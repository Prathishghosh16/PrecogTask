# %% [markdown]
# # Knowledge Graph Rule Discovery
#
# This notebook discovers logical rules in a knowledge graph and validates them with:
# - **Confidence**: Fraction of times the rule holds
# - **Support**: Number of instances where the rule applies
# - **Concrete examples**: Actual instances from the dataset

# %% [markdown]
# ## Rules mined:
# 1) Inverese Rule
# 2) Horn Clause (A->B->C) => (A<->C)
# 3) Horn Clause but for more than 3 people involved.
# 4) Triangle Rules

# %%
import pandas as pd
from collections import defaultdict
from itertools import combinations

# Step 1: Parse the graph data
def parse_graph(file_path):
    """Parse the graph file and return a list of triples (subject, relation, object)"""
    triples = []
    with open(file_path, 'r') as f:
        for line in f:
            line = line.strip()
            if line:
                parts = line.split()
                if len(parts) == 3:
                    subject, relation, obj = parts
                    triples.append((subject, relation, obj))
    return triples

# Step 2: Build data structures for efficient querying
def build_graph_structures(triples):
    """Build data structures to store relations"""
    # Dictionary: person -> list of (relation, target_person)
    outgoing = defaultdict(list)
    # Dictionary: person -> list of (relation, source_person)
    incoming = defaultdict(list)
    # Set of all unique persons
    persons = set()
    # Set of all unique relations
    relations = set()
    
    for subject, relation, obj in triples:
        outgoing[subject].append((relation, obj))
        incoming[obj].append((relation, subject))
        persons.add(subject)
        persons.add(obj)
        relations.add(relation)
    
    return outgoing, incoming, persons, relations

# Step 3: Mine rules - find if B->A implies A->B patterns
def mine_reciprocal_rules(triples, outgoing):
    """
    For each triple (B, relation1, A), check if (A, relation2, B) exists
    Count how often each pattern occurs
    """
    rule_counts = defaultdict(int)  # (relation1, relation2) -> count
    relation_counts = defaultdict(int)  # relation1 -> total count
    
    for subject, relation1, obj in triples:
        relation_counts[relation1] += 1
        
        # Check all relations from obj back to subject
        if obj in outgoing:
            for relation2, target in outgoing[obj]:
                if target == subject:
                    rule_counts[(relation1, relation2)] += 1
    
    return rule_counts, relation_counts
# Step 4: Calculate support and confidence
def calculate_metrics(rule_counts, relation_counts, total_triples):
    """Calculate support and confidence for each rule"""
    results = []
    
    for (rel1, rel2), count in rule_counts.items():
        support = count / total_triples if total_triples > 0 else 0
        confidence = count / relation_counts[rel1] if relation_counts[rel1] > 0 else 0
        
        results.append({
            'Rule': f'If B {rel1} A, then A {rel2} B',
            'Relation1': rel1,
            'Relation2': rel2,
            'Count': count,
            'Support': support,
            'Confidence': confidence,
            'Total_Relation1': relation_counts[rel1]
        })
    
    return pd.DataFrame(results).sort_values('Count', ascending=False)

# Main execution
# Read and parse the file
file_path = 'train.txt'  # Change this to your file path
triples = parse_graph(file_path)

# Build graph structures
outgoing, incoming, persons, relations = build_graph_structures(triples)

# Mine reciprocal rules
rule_counts, relation_counts = mine_reciprocal_rules(triples, outgoing)

# Calculate metrics
total_triples = len(triples)
results_df = calculate_metrics(rule_counts, relation_counts, total_triples)

# Display results
print(f"Total triples: {total_triples}")
print(f"Total unique persons: {len(persons)}")
print(f"Total unique relations: {len(relations)}\n")
print("Reciprocal Rules Found:")
print(results_df.to_string(index=False))

# Optional: Show sample of the graph structure
print("\n\nSample of outgoing relations:")
for person in list(persons)[:5]:
    if person in outgoing:
        print(f"{person}: {outgoing[person][:3]}")
# Out:
# Total triples: 13821
# Total unique persons: 1316
# Total unique relations: 28
#
# Reciprocal Rules Found:
#                                                        Rule                    Relation1                    Relation2  Count  Support  Confidence  Total_Relation1
#                   If B grandfatherOf A, then A grandsonOf B                grandfatherOf                   grandsonOf    407 0.029448    0.500615              813
#                   If B grandsonOf A, then A grandfatherOf B                   grandsonOf                grandfatherOf    407 0.029448    0.500000              814
#                   If B grandsonOf A, then A grandmotherOf B                   grandsonOf                grandmotherOf    407 0.029448    0.500000              814
#                   If B grandmotherOf A, then A grandsonOf B                grandmotherOf                   grandsonOf    407 0.029448    0.500615              813
#              If B granddaughterOf A, then A grandmotherOf B              granddaughterOf                grandmotherOf    406 0.029376    0.500000              812
#              If B granddaughterOf A, then A grandfatherOf B              granddaughterOf                grandfatherOf    406 0.029376    0.500000              812
#              If B grandfatherOf A, then A granddaughterOf B                grandfatherOf              granddaughterOf    406 0.029376    0.499385              813
#              If B grandmotherOf A, then A granddaughterOf B                grandmotherOf              granddaughterOf    406 0.029376    0.499385              813
#                          If B sisterOf A, then A sisterOf B                     sisterOf                     sisterOf    328 0.023732    0.515723              636
#                        If B daughterOf A, then A fatherOf B                   daughterOf                     fatherOf    316 0.022864    0.503185              628
#                        If B fatherOf A, then A daughterOf B                     fatherOf                   daughterOf    316 0.022864    0.431105              733
#         If B greatGrandsonOf A, then A greatGrandmotherOf B              greatGrandsonOf           greatGrandmotherOf    312 0.022574    0.500000              624
#         If B greatGrandfatherOf A, then A greatGrandsonOf B           greatGrandfatherOf              greatGrandsonOf    312 0.022574    0.505673              617
#         If B greatGrandmotherOf A, then A greatGrandsonOf B           greatGrandmotherOf              greatGrandsonOf    312 0.022574    0.505673              617
#         If B greatGrandsonOf A, then A greatGrandfatherOf B              greatGrandsonOf           greatGrandfatherOf    312 0.022574    0.500000              624
#                         If B brotherOf A, then A sisterOf B                    brotherOf                     sisterOf    308 0.022285    0.540351              570
#                         If B sisterOf A, then A brotherOf B                     sisterOf                    brotherOf    308 0.022285    0.484277              636
#    If B greatGrandfatherOf A, then A greatGranddaughterOf B           greatGrandfatherOf         greatGranddaughterOf    305 0.022068    0.494327              617
#    If B greatGrandmotherOf A, then A greatGranddaughterOf B           greatGrandmotherOf         greatGranddaughterOf    305 0.022068    0.494327              617
#    If B greatGranddaughterOf A, then A greatGrandfatherOf B         greatGranddaughterOf           greatGrandfatherOf    305 0.022068    0.500000              610
#    If B greatGranddaughterOf A, then A greatGrandmotherOf B         greatGranddaughterOf           greatGrandmotherOf    305 0.022068    0.500000              610
#                            If B nephewOf A, then A auntOf B                     nephewOf                       auntOf    298 0.021561    0.579767              514
#                            If B auntOf A, then A nephewOf B                       auntOf                     nephewOf    298 0.021561    0.535971              556
#                             If B sonOf A, then A fatherOf B                        sonOf                     fatherOf    292 0.021127    0.486667              600
#                             If B fatherOf A, then A sonOf B                     fatherOf                        sonOf    292 0.021127    0.398363              733
#                        If B brotherOf A, then A brotherOf B                    brotherOf                    brotherOf    262 0.018957    0.459649              570
#                             If B nieceOf A, then A auntOf B                      nieceOf                       auntOf    258 0.018667    0.520161              496
#                             If B auntOf A, then A nieceOf B                       auntOf                      nieceOf    258 0.018667    0.464029              556
#                            If B nieceOf A, then A uncleOf B                      nieceOf                      uncleOf    238 0.017220    0.479839              496
#                            If B uncleOf A, then A nieceOf B                      uncleOf                      nieceOf    238 0.017220    0.524229              454
#                  If B girlCousinOf A, then A girlCousinOf B                 girlCousinOf                 girlCousinOf    236 0.017075    0.530337              445
#                        If B motherOf A, then A daughterOf B                     motherOf                   daughterOf    224 0.016207    0.305593              733
#                        If B daughterOf A, then A motherOf B                   daughterOf                     motherOf    224 0.016207    0.356688              628
#                             If B sonOf A, then A motherOf B                        sonOf                     motherOf    220 0.015918    0.366667              600
#                             If B motherOf A, then A sonOf B                     motherOf                        sonOf    220 0.015918    0.300136              733
#                           If B uncleOf A, then A nephewOf B                      uncleOf                     nephewOf    216 0.015628    0.475771              454
#                           If B nephewOf A, then A uncleOf B                     nephewOf                      uncleOf    216 0.015628    0.420233              514
#                   If B boyCousinOf A, then A girlCousinOf B                  boyCousinOf                 girlCousinOf    209 0.015122    0.534527              391
#                   If B girlCousinOf A, then A boyCousinOf B                 girlCousinOf                  boyCousinOf    209 0.015122    0.469663              445
#                    If B boyCousinOf A, then A boyCousinOf B                  boyCousinOf                  boyCousinOf    182 0.013168    0.465473              391
#   If B secondAuntOf A, then A boyFirstCousinOnceRemovedOf B                 secondAuntOf  boyFirstCousinOnceRemovedOf     98 0.007091    0.560000              175
#   If B boyFirstCousinOnceRemovedOf A, then A secondAuntOf B  boyFirstCousinOnceRemovedOf                 secondAuntOf     98 0.007091    0.544444              180
#  If B boyFirstCousinOnceRemovedOf A, then A secondUncleOf B  boyFirstCousinOnceRemovedOf                secondUncleOf     82 0.005933    0.455556              180
#  If B secondUncleOf A, then A boyFirstCousinOnceRemovedOf B                secondUncleOf  boyFirstCousinOnceRemovedOf     82 0.005933    0.518987              158
#  If B girlFirstCousinOnceRemovedOf A, then A secondAuntOf B girlFirstCousinOnceRemovedOf                 secondAuntOf     77 0.005571    0.503268              153
#  If B secondAuntOf A, then A girlFirstCousinOnceRemovedOf B                 secondAuntOf girlFirstCousinOnceRemovedOf     77 0.005571    0.440000              175
# If B secondUncleOf A, then A girlFirstCousinOnceRemovedOf B                secondUncleOf girlFirstCousinOnceRemovedOf     76 0.005499    0.481013              158
# If B girlFirstCousinOnceRemovedOf A, then A secondUncleOf B girlFirstCousinOnceRemovedOf                secondUncleOf     76 0.005499    0.496732              153
#       If B boySecondCousinOf A, then A girlSecondCousinOf B            boySecondCousinOf           girlSecondCousinOf     40 0.002894    0.588235               68
#       If B girlSecondCousinOf A, then A boySecondCousinOf B           girlSecondCousinOf            boySecondCousinOf     40 0.002894    0.645161               62
#        If B boySecondCousinOf A, then A boySecondCousinOf B            boySecondCousinOf            boySecondCousinOf     28 0.002026    0.411765               68
#      If B girlSecondCousinOf A, then A girlSecondCousinOf B           girlSecondCousinOf           girlSecondCousinOf     22 0.001592    0.354839               62
#
#
# Sample of outgoing relations:
# sebastian320: [('fatherOf', 'marko317'), ('grandfatherOf', 'helga315'), ('grandfatherOf', 'elias338')]
# natalie89: [('sisterOf', 'emily102'), ('girlSecondCousinOf', 'nico91'), ('girlSecondCousinOf', 'lukas93')]
# sarah893: [('sisterOf', 'noah886'), ('sisterOf', 'jan874'), ('daughterOf', 'natalie877')]
# karin651: [('motherOf', 'gertrude637'), ('grandmotherOf', 'valentin638')]
# mia595: [('sisterOf', 'sarah592'), ('sisterOf', 'marcel580'), ('greatAuntOf', 'selina588')]

# %% [markdown]
# # The above list is that of all the inverse relations found in the graph.
# Ideally for inverse relations the confidence should be way higher at 90%. However most have a confidence of about 50%. In the context of a family knowledge graph we can conclude that this is due to the graph being sparse and that lot of the entries are simply missing.
# Ideally the support should be more than 5% but most relations have a support of arround 2%.
#
# All of this points to the conclusion that the graph is not properly populated and several edges in this graph are missing.

# %% [markdown]
# ## The Horn Clause

# %%
import pandas as pd
from collections import defaultdict
from itertools import product

# Step 1: Parse the graph data (same as before)
def parse_graph(file_path):
    """Parse the graph file and return a list of triples (subject, relation, object)"""
    triples = []
    with open(file_path, 'r') as f:
        for line in f:
            line = line.strip()
            if line:
                parts = line.split()
                if len(parts) == 3:
                    subject, relation, obj = parts
                    triples.append((subject, relation, obj))
    return triples

# Step 2: Build data structures (same as before)
def build_graph_structures(triples):
    """Build data structures to store relations"""
    outgoing = defaultdict(list)
    incoming = defaultdict(list)
    persons = set()
    relations = set()
    
    for subject, relation, obj in triples:
        outgoing[subject].append((relation, obj))
        incoming[obj].append((relation, subject))
        persons.add(subject)
        persons.add(obj)
        relations.add(relation)
    
    return outgoing, incoming, persons, relations

# Step 3: Mine Horn clauses
def mine_horn_clauses(triples, outgoing):
    """
    Mine rules of the form: relation1(X,Y) ∧ relation2(Y,Z) → relation3(X,Z)
    
    For each pair of triples:
    - (X, relation1, Y) and (Y, relation2, Z)
    Check if there exists (X, relation3, Z)
    """
    # Build index for quick lookup: (X, Z) -> set of relations
    xz_relations = defaultdict(set)
    for subject, relation, obj in triples:
        xz_relations[(subject, obj)].add(relation)
    
    # Count potential body patterns and successful head patterns
    body_counts = defaultdict(int)  # (relation1, relation2) -> count of X,Y,Z satisfying body
    rule_counts = defaultdict(int)  # (relation1, relation2, relation3) -> count of full rule satisfaction
    
    # For each triple (X, relation1, Y)
    for x, relation1, y in triples:
        # Check if Y has outgoing edges (Y, relation2, Z)
        if y in outgoing:
            for relation2, z in outgoing[y]:
                # We have: relation1(X, Y) ∧ relation2(Y, Z)
                body_counts[(relation1, relation2)] += 1
                
                # Check if relation3(X, Z) exists for any relation3
                if (x, z) in xz_relations:
                    for relation3 in xz_relations[(x, z)]:
                        # We found: relation1(X,Y) ∧ relation2(Y,Z) → relation3(X,Z)
                        rule_counts[(relation1, relation2, relation3)] += 1
    
    return rule_counts, body_counts

# Step 4: Calculate metrics for Horn clauses
def calculate_horn_metrics(rule_counts, body_counts, total_triples):
    """Calculate support and confidence for each Horn clause"""
    results = []
    
    for (rel1, rel2, rel3), count in rule_counts.items():
        body_count = body_counts[(rel1, rel2)]
        
        # Support: proportion of all triples
        support = count / total_triples if total_triples > 0 else 0
        
        # Confidence: proportion of body occurrences that lead to head
        confidence = count / body_count if body_count > 0 else 0
        
        results.append({
            'Rule': f'{rel1}(X,Y) ∧ {rel2}(Y,Z) → {rel3}(X,Z)',
            'Relation1': rel1,
            'Relation2': rel2,
            'Relation3': rel3,
            'Count': count,
            'Body_Count': body_count,
            'Support': support,
            'Confidence': confidence
        })
    
    return pd.DataFrame(results).sort_values('Count', ascending=False)

# Step 5: Find examples for a specific rule
def find_rule_examples(triples, outgoing, rel1, rel2, rel3, max_examples=5):
    """Find concrete examples of a specific Horn clause"""
    examples = []
    xz_relations = defaultdict(set)
    
    for subject, relation, obj in triples:
        xz_relations[(subject, obj)].add(relation)
    
    for x, relation1, y in triples:
        if relation1 == rel1 and y in outgoing:
            for relation2, z in outgoing[y]:
                if relation2 == rel2:
                    if (x, z) in xz_relations and rel3 in xz_relations[(x, z)]:
                        examples.append({
                            'X': x,
                            'Y': y,
                            'Z': z,
                            f'{rel1}(X,Y)': True,
                            f'{rel2}(Y,Z)': True,
                            f'{rel3}(X,Z)': True
                        })
                        if len(examples) >= max_examples:
                            return pd.DataFrame(examples)
    
    return pd.DataFrame(examples)

# Main execution
# Read and parse the file
file_path = 'train.txt'  # Change this to your file path
triples = parse_graph(file_path)

# Build graph structures
outgoing, incoming, persons, relations = build_graph_structures(triples)

# Mine Horn clauses
rule_counts, body_counts = mine_horn_clauses(triples, outgoing)

# Calculate metrics
total_triples = len(triples)
horn_results_df = calculate_horn_metrics(rule_counts, body_counts, total_triples)

# Display results
print(f"Total triples: {total_triples}")
print(f"Total unique persons: {len(persons)}")
print(f"Total unique relations: {len(relations)}\n")
print("Horn Clause Rules Found:")
print(horn_results_df.to_string(index=False))

# Optional: Show examples for top rules
if len(horn_results_df) > 0:
    print("\n" + "="*80)
    print("Examples for top 3 rules:")
    print("="*80)
    
    for idx, row in horn_results_df.head(3).iterrows():
        print(f"\nRule: {row['Rule']}")
        print(f"Confidence: {row['Confidence']:.2%}, Count: {row['Count']}")
        examples = find_rule_examples(triples, outgoing, 
                                      row['Relation1'], 
                                      row['Relation2'], 
                                      row['Relation3'], 
                                      max_examples=3)
        if not examples.empty:
            print(examples.to_string(index=False))
        print("-"*80)

# **What this code does:**

# 1. **Mines Horn clauses** of the form `relation1(X,Y) ∧ relation2(Y,Z) → relation3(X,Z)`
# 2. **Calculates metrics:**
#    - **Count**: How many times the full rule holds
#    - **Body_Count**: How many times the body (premise) occurs
#    - **Confidence**: What percentage of body occurrences lead to the head (conclusion)
#    - **Support**: Overall frequency in the dataset

# 3. **Shows concrete examples** for the top rules found

# **Example output you might see:**
# ```
# Rule: motherOf(X,Y) ∧ motherOf(Y,Z) → grandmotherOf(X,Z)
# Confidence: 95%, Count: 42
# Out:
# Total triples: 13821
# Total unique persons: 1316
# Total unique relations: 28
#
# Horn Clause Rules Found:
#                                                                                            Rule                    Relation1                    Relation2                    Relation3  Count  Body_Count  Support  Confidence
#                                     sisterOf(X,Y) ∧ granddaughterOf(Y,Z) → granddaughterOf(X,Z)                     sisterOf              granddaughterOf              granddaughterOf    772         772 0.055857    1.000000
#                                       granddaughterOf(X,Y) ∧ grandmotherOf(Y,Z) → sisterOf(X,Z)              granddaughterOf                grandmotherOf                     sisterOf    747        1598 0.054048    0.467459
#                                         grandfatherOf(X,Y) ∧ sisterOf(Y,Z) → grandfatherOf(X,Z)                grandfatherOf                     sisterOf                grandfatherOf    747         747 0.054048    1.000000
#                                       granddaughterOf(X,Y) ∧ grandfatherOf(Y,Z) → sisterOf(X,Z)              granddaughterOf                grandfatherOf                     sisterOf    747        1598 0.054048    0.467459
#                                         grandmotherOf(X,Y) ∧ sisterOf(Y,Z) → grandmotherOf(X,Z)                grandmotherOf                     sisterOf                grandmotherOf    747         747 0.054048    1.000000
#                                         brotherOf(X,Y) ∧ granddaughterOf(Y,Z) → grandsonOf(X,Z)                    brotherOf              granddaughterOf                   grandsonOf    722         722 0.052239    1.000000
#                                          sisterOf(X,Y) ∧ grandsonOf(Y,Z) → granddaughterOf(X,Z)                     sisterOf                   grandsonOf              granddaughterOf    722         722 0.052239    1.000000
#                                           grandsonOf(X,Y) ∧ grandfatherOf(Y,Z) → brotherOf(X,Z)                   grandsonOf                grandfatherOf                    brotherOf    673        1471 0.048694    0.457512
#                                        grandmotherOf(X,Y) ∧ brotherOf(Y,Z) → grandmotherOf(X,Z)                grandmotherOf                    brotherOf                grandmotherOf    673         673 0.048694    1.000000
#                                           grandsonOf(X,Y) ∧ grandmotherOf(Y,Z) → brotherOf(X,Z)                   grandsonOf                grandmotherOf                    brotherOf    673        1471 0.048694    0.457512
#                                        grandfatherOf(X,Y) ∧ brotherOf(Y,Z) → grandfatherOf(X,Z)                grandfatherOf                    brotherOf                grandfatherOf    673         673 0.048694    1.000000
#                                              brotherOf(X,Y) ∧ grandsonOf(Y,Z) → grandsonOf(X,Z)                    brotherOf                   grandsonOf                   grandsonOf    624         624 0.045149    1.000000
#                                     nephewOf(X,Y) ∧ granddaughterOf(Y,Z) → greatGrandsonOf(X,Z)                     nephewOf              granddaughterOf              greatGrandsonOf    608         608 0.043991    1.000000
#                                       auntOf(X,Y) ∧ greatGrandsonOf(Y,Z) → granddaughterOf(X,Z)                       auntOf              greatGrandsonOf              granddaughterOf    608         644 0.043991    0.944099
#                                      grandfatherOf(X,Y) ∧ auntOf(Y,Z) → greatGrandfatherOf(X,Z)                grandfatherOf                       auntOf           greatGrandfatherOf    562         562 0.040663    1.000000
#                                    granddaughterOf(X,Y) ∧ greatGrandfatherOf(Y,Z) → auntOf(X,Z)              granddaughterOf           greatGrandfatherOf                       auntOf    562        1024 0.040663    0.548828
#                                      grandmotherOf(X,Y) ∧ auntOf(Y,Z) → greatGrandmotherOf(X,Z)                grandmotherOf                       auntOf           greatGrandmotherOf    562         562 0.040663    1.000000
#                                    granddaughterOf(X,Y) ∧ greatGrandmotherOf(Y,Z) → auntOf(X,Z)              granddaughterOf           greatGrandmotherOf                       auntOf    562        1024 0.040663    0.548828
#                                      nieceOf(X,Y) ∧ grandsonOf(Y,Z) → greatGranddaughterOf(X,Z)                      nieceOf                   grandsonOf         greatGranddaughterOf    544         544 0.039360    1.000000
#                                      uncleOf(X,Y) ∧ greatGranddaughterOf(Y,Z) → grandsonOf(X,Z)                      uncleOf         greatGranddaughterOf                   grandsonOf    544         612 0.039360    0.888889
#                                    greatGrandfatherOf(X,Y) ∧ nephewOf(Y,Z) → grandfatherOf(X,Z)           greatGrandfatherOf                     nephewOf                grandfatherOf    541         593 0.039143    0.912310
#                                    greatGrandmotherOf(X,Y) ∧ nephewOf(Y,Z) → grandmotherOf(X,Z)           greatGrandmotherOf                     nephewOf                grandmotherOf    541         593 0.039143    0.912310
#                                       greatGrandsonOf(X,Y) ∧ grandmotherOf(Y,Z) → nephewOf(X,Z)              greatGrandsonOf                grandmotherOf                     nephewOf    541        1033 0.039143    0.523717
#                                       greatGrandsonOf(X,Y) ∧ grandfatherOf(Y,Z) → nephewOf(X,Z)              greatGrandsonOf                grandfatherOf                     nephewOf    541        1033 0.039143    0.523717
#                                                   sisterOf(X,Y) ∧ sisterOf(Y,Z) → sisterOf(X,Z)                     sisterOf                     sisterOf                     sisterOf    540         868 0.039071    0.622120
#                                   greatGranddaughterOf(X,Y) ∧ grandmotherOf(Y,Z) → nieceOf(X,Z)         greatGranddaughterOf                grandmotherOf                      nieceOf    530         988 0.038347    0.536437
#                                   greatGranddaughterOf(X,Y) ∧ grandfatherOf(Y,Z) → nieceOf(X,Z)         greatGranddaughterOf                grandfatherOf                      nieceOf    530         988 0.038347    0.536437
#                                     greatGrandfatherOf(X,Y) ∧ nieceOf(Y,Z) → grandfatherOf(X,Z)           greatGrandfatherOf                      nieceOf                grandfatherOf    530         588 0.038347    0.901361
#                                     greatGrandmotherOf(X,Y) ∧ nieceOf(Y,Z) → grandmotherOf(X,Z)           greatGrandmotherOf                      nieceOf                grandmotherOf    530         588 0.038347    0.901361
#                                               sisterOf(X,Y) ∧ daughterOf(Y,Z) → daughterOf(X,Z)                     sisterOf                   daughterOf                   daughterOf    518         518 0.037479    1.000000
#                                  auntOf(X,Y) ∧ greatGranddaughterOf(Y,Z) → granddaughterOf(X,Z)                       auntOf         greatGranddaughterOf              granddaughterOf    516         564 0.037334    0.914894
#                           sisterOf(X,Y) ∧ greatGranddaughterOf(Y,Z) → greatGranddaughterOf(X,Z)                     sisterOf         greatGranddaughterOf         greatGranddaughterOf    516         516 0.037334    1.000000
#                                 nieceOf(X,Y) ∧ granddaughterOf(Y,Z) → greatGranddaughterOf(X,Z)                      nieceOf              granddaughterOf         greatGranddaughterOf    516         516 0.037334    1.000000
#                                              daughterOf(X,Y) ∧ grandfatherOf(Y,Z) → auntOf(X,Z)                   daughterOf                grandfatherOf                       auntOf    511         874 0.036973    0.584668
#                                     grandfatherOf(X,Y) ∧ uncleOf(Y,Z) → greatGrandfatherOf(X,Z)                grandfatherOf                      uncleOf           greatGrandfatherOf    509         509 0.036828    1.000000
#                                     grandmotherOf(X,Y) ∧ uncleOf(Y,Z) → greatGrandmotherOf(X,Z)                grandmotherOf                      uncleOf           greatGrandmotherOf    509         509 0.036828    1.000000
#                                        grandsonOf(X,Y) ∧ greatGrandmotherOf(Y,Z) → uncleOf(X,Z)                   grandsonOf           greatGrandmotherOf                      uncleOf    509         997 0.036828    0.510532
#                                        grandsonOf(X,Y) ∧ greatGrandfatherOf(Y,Z) → uncleOf(X,Z)                   grandsonOf           greatGrandfatherOf                      uncleOf    509         997 0.036828    0.510532
#                                                fatherOf(X,Y) ∧ auntOf(Y,Z) → grandfatherOf(X,Z)                     fatherOf                       auntOf                grandfatherOf    489         489 0.035381    1.000000
#                                                motherOf(X,Y) ∧ auntOf(Y,Z) → grandmotherOf(X,Z)                     motherOf                       auntOf                grandmotherOf    489         489 0.035381    1.000000
#                               greatGrandmotherOf(X,Y) ∧ sisterOf(Y,Z) → greatGrandmotherOf(X,Z)           greatGrandmotherOf                     sisterOf           greatGrandmotherOf    483         483 0.034947    1.000000
#                             greatGranddaughterOf(X,Y) ∧ greatGrandmotherOf(Y,Z) → sisterOf(X,Z)         greatGranddaughterOf           greatGrandmotherOf                     sisterOf    483        1310 0.034947    0.368702
#                               greatGrandfatherOf(X,Y) ∧ sisterOf(Y,Z) → greatGrandfatherOf(X,Z)           greatGrandfatherOf                     sisterOf           greatGrandfatherOf    483         483 0.034947    1.000000
#                             greatGranddaughterOf(X,Y) ∧ greatGrandfatherOf(Y,Z) → sisterOf(X,Z)         greatGranddaughterOf           greatGrandfatherOf                     sisterOf    483        1310 0.034947    0.368702
#                                                  sisterOf(X,Y) ∧ brotherOf(Y,Z) → sisterOf(X,Z)                     sisterOf                    brotherOf                     sisterOf    482         790 0.034874    0.610127
#                                                 brotherOf(X,Y) ∧ sisterOf(Y,Z) → brotherOf(X,Z)                    brotherOf                     sisterOf                    brotherOf    482         790 0.034874    0.610127
#                                           uncleOf(X,Y) ∧ greatGrandsonOf(Y,Z) → grandsonOf(X,Z)                      uncleOf              greatGrandsonOf                   grandsonOf    474         542 0.034296    0.874539
#                                          nephewOf(X,Y) ∧ grandsonOf(Y,Z) → greatGrandsonOf(X,Z)                     nephewOf                   grandsonOf              greatGrandsonOf    474         474 0.034296    1.000000
#                                 girlCousinOf(X,Y) ∧ granddaughterOf(Y,Z) → granddaughterOf(X,Z)                 girlCousinOf              granddaughterOf              granddaughterOf    472         612 0.034151    0.771242
#                       girlCousinOf(X,Y) ∧ greatGranddaughterOf(Y,Z) → greatGranddaughterOf(X,Z)                 girlCousinOf         greatGranddaughterOf         greatGranddaughterOf    472         488 0.034151    0.967213
#                                                       sisterOf(X,Y) ∧ auntOf(Y,Z) → auntOf(X,Z)                     sisterOf                       auntOf                       auntOf    462         736 0.033427    0.627717
#                           greatGrandmotherOf(X,Y) ∧ girlCousinOf(Y,Z) → greatGrandmotherOf(X,Z)           greatGrandmotherOf                 girlCousinOf           greatGrandmotherOf    460         483 0.033283    0.952381
#                         greatGranddaughterOf(X,Y) ∧ greatGrandfatherOf(Y,Z) → girlCousinOf(X,Z)         greatGranddaughterOf           greatGrandfatherOf                 girlCousinOf    460        1310 0.033283    0.351145
#                         greatGranddaughterOf(X,Y) ∧ greatGrandmotherOf(Y,Z) → girlCousinOf(X,Z)         greatGranddaughterOf           greatGrandmotherOf                 girlCousinOf    460        1310 0.033283    0.351145
#                           greatGrandfatherOf(X,Y) ∧ girlCousinOf(Y,Z) → greatGrandfatherOf(X,Z)           greatGrandfatherOf                 girlCousinOf           greatGrandfatherOf    460         483 0.033283    0.952381
#                                                 grandsonOf(X,Y) ∧ motherOf(Y,Z) → nephewOf(X,Z)                   grandsonOf                     motherOf                     nephewOf    458         820 0.033138    0.558537
#                                              grandmotherOf(X,Y) ∧ nephewOf(Y,Z) → motherOf(X,Z)                grandmotherOf                     nephewOf                     motherOf    458         679 0.033138    0.674521
#                                              grandfatherOf(X,Y) ∧ nephewOf(Y,Z) → fatherOf(X,Z)                grandfatherOf                     nephewOf                     fatherOf    458         679 0.033138    0.674521
#                                                 grandsonOf(X,Y) ∧ fatherOf(Y,Z) → nephewOf(X,Z)                   grandsonOf                     fatherOf                     nephewOf    458         820 0.033138    0.558537
#                                               nephewOf(X,Y) ∧ daughterOf(Y,Z) → grandsonOf(X,Z)                     nephewOf                   daughterOf                   grandsonOf    456         456 0.032993    1.000000
#                                                 auntOf(X,Y) ∧ grandsonOf(Y,Z) → daughterOf(X,Z)                       auntOf                   grandsonOf                   daughterOf    456         774 0.032993    0.589147
#                                                  fatherOf(X,Y) ∧ brotherOf(Y,Z) → fatherOf(X,Z)                     fatherOf                    brotherOf                     fatherOf    454         504 0.032849    0.900794
#                                                  motherOf(X,Y) ∧ brotherOf(Y,Z) → motherOf(X,Z)                     motherOf                    brotherOf                     motherOf    454         504 0.032849    0.900794
#                                                   brotherOf(X,Y) ∧ daughterOf(Y,Z) → sonOf(X,Z)                    brotherOf                   daughterOf                        sonOf    453         453 0.032776    1.000000
#                                                    sisterOf(X,Y) ∧ sonOf(Y,Z) → daughterOf(X,Z)                     sisterOf                        sonOf                   daughterOf    453         453 0.032776    1.000000
#                                sisterOf(X,Y) ∧ greatGrandsonOf(Y,Z) → greatGranddaughterOf(X,Z)                     sisterOf              greatGrandsonOf         greatGranddaughterOf    450         450 0.032559    1.000000
#                               brotherOf(X,Y) ∧ greatGranddaughterOf(Y,Z) → greatGrandsonOf(X,Z)                    brotherOf         greatGranddaughterOf              greatGrandsonOf    450         450 0.032559    1.000000
#                            girlCousinOf(X,Y) ∧ greatGrandsonOf(Y,Z) → greatGranddaughterOf(X,Z)                 girlCousinOf              greatGrandsonOf         greatGranddaughterOf    448         460 0.032414    0.973913
#                             boyCousinOf(X,Y) ∧ greatGranddaughterOf(Y,Z) → greatGrandsonOf(X,Z)                  boyCousinOf         greatGranddaughterOf              greatGrandsonOf    448         478 0.032414    0.937238
#                                     grandfatherOf(X,Y) ∧ girlCousinOf(Y,Z) → grandfatherOf(X,Z)                grandfatherOf                 girlCousinOf                grandfatherOf    445         573 0.032197    0.776614
#                                   granddaughterOf(X,Y) ∧ grandfatherOf(Y,Z) → girlCousinOf(X,Z)              granddaughterOf                grandfatherOf                 girlCousinOf    445        1598 0.032197    0.278473
#                                     grandmotherOf(X,Y) ∧ girlCousinOf(Y,Z) → grandmotherOf(X,Z)                grandmotherOf                 girlCousinOf                grandmotherOf    445         573 0.032197    0.776614
#                                   granddaughterOf(X,Y) ∧ grandmotherOf(Y,Z) → girlCousinOf(X,Z)              granddaughterOf                grandmotherOf                 girlCousinOf    445        1598 0.032197    0.278473
#                                                      auntOf(X,Y) ∧ brotherOf(Y,Z) → auntOf(X,Z)                       auntOf                    brotherOf                       auntOf    444         444 0.032125    1.000000
#                                                    nephewOf(X,Y) ∧ auntOf(Y,Z) → brotherOf(X,Z)                     nephewOf                       auntOf                    brotherOf    444        1044 0.032125    0.425287
#                                                      nieceOf(X,Y) ∧ auntOf(Y,Z) → sisterOf(X,Z)                      nieceOf                       auntOf                     sisterOf    442        1044 0.031980    0.423372
#                                                       auntOf(X,Y) ∧ sisterOf(Y,Z) → auntOf(X,Z)                       auntOf                     sisterOf                       auntOf    442         442 0.031980    1.000000
#                                                   nephewOf(X,Y) ∧ sisterOf(Y,Z) → nephewOf(X,Z)                     nephewOf                     sisterOf                     nephewOf    440         738 0.031836    0.596206
#                                                     auntOf(X,Y) ∧ nephewOf(Y,Z) → sisterOf(X,Z)                       auntOf                     nephewOf                     sisterOf    440         768 0.031836    0.572917
#                                                 daughterOf(X,Y) ∧ fatherOf(Y,Z) → sisterOf(X,Z)                   daughterOf                     fatherOf                     sisterOf    439         755 0.031763    0.581457
#                                               grandfatherOf(X,Y) ∧ nieceOf(Y,Z) → fatherOf(X,Z)                grandfatherOf                      nieceOf                     fatherOf    438         697 0.031691    0.628407
#                                               grandmotherOf(X,Y) ∧ nieceOf(Y,Z) → motherOf(X,Z)                grandmotherOf                      nieceOf                     motherOf    438         697 0.031691    0.628407
#                                             granddaughterOf(X,Y) ∧ fatherOf(Y,Z) → nieceOf(X,Z)              granddaughterOf                     fatherOf                      nieceOf    438         792 0.031691    0.553030
#                                             granddaughterOf(X,Y) ∧ motherOf(Y,Z) → nieceOf(X,Z)              granddaughterOf                     motherOf                      nieceOf    438         792 0.031691    0.553030
#                              greatGrandmotherOf(X,Y) ∧ brotherOf(Y,Z) → greatGrandmotherOf(X,Z)           greatGrandmotherOf                    brotherOf           greatGrandmotherOf    437         437 0.031619    1.000000
#                              greatGrandfatherOf(X,Y) ∧ brotherOf(Y,Z) → greatGrandfatherOf(X,Z)           greatGrandfatherOf                    brotherOf           greatGrandfatherOf    437         437 0.031619    1.000000
#                                 greatGrandsonOf(X,Y) ∧ greatGrandmotherOf(Y,Z) → brotherOf(X,Z)              greatGrandsonOf           greatGrandmotherOf                    brotherOf    437        1217 0.031619    0.359080
#                                 greatGrandsonOf(X,Y) ∧ greatGrandfatherOf(Y,Z) → brotherOf(X,Z)              greatGrandsonOf           greatGrandfatherOf                    brotherOf    437        1217 0.031619    0.359080
#                                           girlCousinOf(X,Y) ∧ sisterOf(Y,Z) → girlCousinOf(X,Z)                 girlCousinOf                     sisterOf                 girlCousinOf    432         432 0.031257    1.000000
#                                           girlCousinOf(X,Y) ∧ girlCousinOf(Y,Z) → sisterOf(X,Z)                 girlCousinOf                 girlCousinOf                     sisterOf    432         896 0.031257    0.482143
#                                           sisterOf(X,Y) ∧ girlCousinOf(Y,Z) → girlCousinOf(X,Z)                     sisterOf                 girlCousinOf                 girlCousinOf    426         426 0.030823    1.000000
#                                                   motherOf(X,Y) ∧ sisterOf(Y,Z) → motherOf(X,Z)                     motherOf                     sisterOf                     motherOf    426         539 0.030823    0.790353
#                                                   fatherOf(X,Y) ∧ sisterOf(Y,Z) → fatherOf(X,Z)                     fatherOf                     sisterOf                     fatherOf    426         539 0.030823    0.790353
#                                    brotherOf(X,Y) ∧ greatGrandsonOf(Y,Z) → greatGrandsonOf(X,Z)                    brotherOf              greatGrandsonOf              greatGrandsonOf    424         424 0.030678    1.000000
#                                                     sonOf(X,Y) ∧ fatherOf(Y,Z) → brotherOf(X,Z)                        sonOf                     fatherOf                    brotherOf    418         710 0.030244    0.588732
#                                       boyCousinOf(X,Y) ∧ granddaughterOf(Y,Z) → grandsonOf(X,Z)                  boyCousinOf              granddaughterOf                   grandsonOf    418         534 0.030244    0.782772
#                                      girlCousinOf(X,Y) ∧ grandsonOf(Y,Z) → granddaughterOf(X,Z)                 girlCousinOf                   grandsonOf              granddaughterOf    418         500 0.030244    0.836000
#                                               motherOf(X,Y) ∧ uncleOf(Y,Z) → grandmotherOf(X,Z)                     motherOf                      uncleOf                grandmotherOf    407         407 0.029448    1.000000
#                                               fatherOf(X,Y) ∧ uncleOf(Y,Z) → grandfatherOf(X,Z)                     fatherOf                      uncleOf                grandfatherOf    407         407 0.029448    1.000000
#                                           nieceOf(X,Y) ∧ daughterOf(Y,Z) → granddaughterOf(X,Z)                      nieceOf                   daughterOf              granddaughterOf    405         405 0.029303    1.000000
#                                            auntOf(X,Y) ∧ granddaughterOf(Y,Z) → daughterOf(X,Z)                       auntOf              granddaughterOf                   daughterOf    405         710 0.029303    0.570423
#                               greatGrandsonOf(X,Y) ∧ greatGrandmotherOf(Y,Z) → boyCousinOf(X,Z)              greatGrandsonOf           greatGrandmotherOf                  boyCousinOf    400        1217 0.028941    0.328677
#                            greatGrandfatherOf(X,Y) ∧ boyCousinOf(Y,Z) → greatGrandfatherOf(X,Z)           greatGrandfatherOf                  boyCousinOf           greatGrandfatherOf    400         417 0.028941    0.959233
#                            greatGrandmotherOf(X,Y) ∧ boyCousinOf(Y,Z) → greatGrandmotherOf(X,Z)           greatGrandmotherOf                  boyCousinOf           greatGrandmotherOf    400         417 0.028941    0.959233
#                               greatGrandsonOf(X,Y) ∧ greatGrandfatherOf(Y,Z) → boyCousinOf(X,Z)              greatGrandsonOf           greatGrandfatherOf                  boyCousinOf    400        1217 0.028941    0.328677
#                                                     sisterOf(X,Y) ∧ nieceOf(Y,Z) → nieceOf(X,Z)                     sisterOf                      nieceOf                      nieceOf    398         398 0.028797    1.000000
#                                                  sonOf(X,Y) ∧ grandfatherOf(Y,Z) → uncleOf(X,Z)                        sonOf                grandfatherOf                      uncleOf    397         774 0.028724    0.512920
#                                                      auntOf(X,Y) ∧ nieceOf(Y,Z) → sisterOf(X,Z)                       auntOf                      nieceOf                     sisterOf    393         697 0.028435    0.563845
#                                                     nieceOf(X,Y) ∧ sisterOf(Y,Z) → nieceOf(X,Z)                      nieceOf                     sisterOf                      nieceOf    393         651 0.028435    0.603687
#                                      grandfatherOf(X,Y) ∧ boyCousinOf(Y,Z) → grandfatherOf(X,Z)                grandfatherOf                  boyCousinOf                grandfatherOf    391         470 0.028290    0.831915
#                                         grandsonOf(X,Y) ∧ grandfatherOf(Y,Z) → boyCousinOf(X,Z)                   grandsonOf                grandfatherOf                  boyCousinOf    391        1471 0.028290    0.265806
#                                         grandsonOf(X,Y) ∧ grandmotherOf(Y,Z) → boyCousinOf(X,Z)                   grandsonOf                grandmotherOf                  boyCousinOf    391        1471 0.028290    0.265806
#                                      grandmotherOf(X,Y) ∧ boyCousinOf(Y,Z) → grandmotherOf(X,Z)                grandmotherOf                  boyCousinOf                grandmotherOf    391         470 0.028290    0.831915
#                                                    sisterOf(X,Y) ∧ nephewOf(Y,Z) → nieceOf(X,Z)                     sisterOf                     nephewOf                      nieceOf    381         381 0.027567    1.000000
#                                                   brotherOf(X,Y) ∧ nieceOf(Y,Z) → nephewOf(X,Z)                    brotherOf                      nieceOf                     nephewOf    381         381 0.027567    1.000000
#                                                brotherOf(X,Y) ∧ brotherOf(Y,Z) → brotherOf(X,Z)                    brotherOf                    brotherOf                    brotherOf    380         642 0.027494    0.591900
#                                                        brotherOf(X,Y) ∧ sonOf(Y,Z) → sonOf(X,Z)                    brotherOf                        sonOf                        sonOf    372         372 0.026916    1.000000
#                                                     brotherOf(X,Y) ∧ auntOf(Y,Z) → uncleOf(X,Z)                    brotherOf                       auntOf                      uncleOf    371         653 0.026843    0.568147
#                                                      sisterOf(X,Y) ∧ uncleOf(Y,Z) → auntOf(X,Z)                     sisterOf                      uncleOf                       auntOf    371         624 0.026843    0.594551
#                                            boyCousinOf(X,Y) ∧ grandsonOf(Y,Z) → grandsonOf(X,Z)                  boyCousinOf                   grandsonOf                   grandsonOf    364         440 0.026337    0.827273
#                                          girlCousinOf(X,Y) ∧ brotherOf(Y,Z) → girlCousinOf(X,Z)                 girlCousinOf                    brotherOf                 girlCousinOf    362         362 0.026192    1.000000
#                                           boyCousinOf(X,Y) ∧ girlCousinOf(Y,Z) → brotherOf(X,Z)                  boyCousinOf                 girlCousinOf                    brotherOf    362         761 0.026192    0.475690
#                                                    nieceOf(X,Y) ∧ brotherOf(Y,Z) → nieceOf(X,Z)                      nieceOf                    brotherOf                      nieceOf    361         599 0.026120    0.602671
#                                                    uncleOf(X,Y) ∧ nieceOf(Y,Z) → brotherOf(X,Z)                      uncleOf                      nieceOf                    brotherOf    361         649 0.026120    0.556240
#                                  boyCousinOf(X,Y) ∧ greatGrandsonOf(Y,Z) → greatGrandsonOf(X,Z)                  boyCousinOf              greatGrandsonOf              greatGrandsonOf    352         374 0.025468    0.941176
#                                              daughterOf(X,Y) ∧ grandmotherOf(Y,Z) → auntOf(X,Z)                   daughterOf                grandmotherOf                       auntOf    350         572 0.025324    0.611888
#                                                   auntOf(X,Y) ∧ girlCousinOf(Y,Z) → auntOf(X,Z)                       auntOf                 girlCousinOf                       auntOf    344         608 0.024890    0.565789
#                                                  nieceOf(X,Y) ∧ auntOf(Y,Z) → girlCousinOf(X,Z)                      nieceOf                       auntOf                 girlCousinOf    344        1044 0.024890    0.329502
#                                            sisterOf(X,Y) ∧ boyCousinOf(Y,Z) → girlCousinOf(X,Z)                     sisterOf                  boyCousinOf                 girlCousinOf    343         343 0.024817    1.000000
#                                           brotherOf(X,Y) ∧ girlCousinOf(Y,Z) → boyCousinOf(X,Z)                    brotherOf                 girlCousinOf                  boyCousinOf    343         343 0.024817    1.000000
#                                                nieceOf(X,Y) ∧ sonOf(Y,Z) → granddaughterOf(X,Z)                      nieceOf                        sonOf              granddaughterOf    340         340 0.024600    1.000000
#                                                uncleOf(X,Y) ∧ granddaughterOf(Y,Z) → sonOf(X,Z)                      uncleOf              granddaughterOf                        sonOf    340         684 0.024600    0.497076
#                                              motherOf(X,Y) ∧ fatherOf(Y,Z) → grandmotherOf(X,Z)                     motherOf                     fatherOf                grandmotherOf    338         338 0.024456    1.000000
#                                              fatherOf(X,Y) ∧ fatherOf(Y,Z) → grandfatherOf(X,Z)                     fatherOf                     fatherOf                grandfatherOf    338         338 0.024456    1.000000
#                                             boyCousinOf(X,Y) ∧ sisterOf(Y,Z) → boyCousinOf(X,Z)                  boyCousinOf                     sisterOf                  boyCousinOf    337         337 0.024383    1.000000
#                                                     nieceOf(X,Y) ∧ uncleOf(Y,Z) → sisterOf(X,Z)                      nieceOf                      uncleOf                     sisterOf    337         834 0.024383    0.404077
#                                            girlCousinOf(X,Y) ∧ boyCousinOf(Y,Z) → sisterOf(X,Z)                 girlCousinOf                  boyCousinOf                     sisterOf    337         731 0.024383    0.461012
#                                                     uncleOf(X,Y) ∧ sisterOf(Y,Z) → uncleOf(X,Z)                      uncleOf                     sisterOf                      uncleOf    337         337 0.024383    1.000000
#                                                 sonOf(X,Y) ∧ grandfatherOf(Y,Z) → fatherOf(X,Z)                        sonOf                grandfatherOf                     fatherOf    328         774 0.023732    0.423773
#                                                  brotherOf(X,Y) ∧ nephewOf(Y,Z) → nephewOf(X,Z)                    brotherOf                     nephewOf                     nephewOf    322         322 0.023298    1.000000
#                                                 girlCousinOf(X,Y) ∧ nieceOf(Y,Z) → nieceOf(X,Z)                 girlCousinOf                      nieceOf                      nieceOf    322         577 0.023298    0.558059
#                                            daughterOf(X,Y) ∧ grandfatherOf(Y,Z) → motherOf(X,Z)                   daughterOf                grandfatherOf                     motherOf    319         874 0.023081    0.364989
#                                          fatherOf(X,Y) ∧ greatGrandsonOf(Y,Z) → grandsonOf(X,Z)                     fatherOf              greatGrandsonOf                   grandsonOf    314         550 0.022719    0.570909
#                                                 nephewOf(X,Y) ∧ greatAuntOf(Y,Z) → uncleOf(X,Z)                     nephewOf                  greatAuntOf                      uncleOf    313         585 0.022647    0.535043
#                                                   auntOf(X,Y) ∧ uncleOf(Y,Z) → greatAuntOf(X,Z)                       auntOf                      uncleOf                  greatAuntOf    313         313 0.022647    1.000000
#                                                     uncleOf(X,Y) ∧ grandsonOf(Y,Z) → sonOf(X,Z)                      uncleOf                   grandsonOf                        sonOf    310         584 0.022430    0.530822
#                                                    nephewOf(X,Y) ∧ sonOf(Y,Z) → grandsonOf(X,Z)                     nephewOf                        sonOf                   grandsonOf    310         310 0.022430    1.000000
#                                              motherOf(X,Y) ∧ motherOf(Y,Z) → grandmotherOf(X,Z)                     motherOf                     motherOf                grandmotherOf    309         309 0.022357    1.000000
#                                              fatherOf(X,Y) ∧ motherOf(Y,Z) → grandfatherOf(X,Z)                     fatherOf                     motherOf                grandfatherOf    309         309 0.022357    1.000000
#                                                     sonOf(X,Y) ∧ motherOf(Y,Z) → brotherOf(X,Z)                        sonOf                     motherOf                    brotherOf    307         527 0.022213    0.582543
#                                                 daughterOf(X,Y) ∧ motherOf(Y,Z) → sisterOf(X,Z)                   daughterOf                     motherOf                     sisterOf    306         530 0.022140    0.577358
#                                                  greatAuntOf(X,Y) ∧ nephewOf(Y,Z) → auntOf(X,Z)                  greatAuntOf                     nephewOf                       auntOf    305         316 0.022068    0.965190
#                                       sonOf(X,Y) ∧ greatGrandfatherOf(Y,Z) → grandfatherOf(X,Z)                        sonOf           greatGrandfatherOf                grandfatherOf    304         513 0.021996    0.592593
#                                                  nephewOf(X,Y) ∧ brotherOf(Y,Z) → nephewOf(X,Z)                     nephewOf                    brotherOf                     nephewOf    304         520 0.021996    0.584615
#                                                   uncleOf(X,Y) ∧ nephewOf(Y,Z) → brotherOf(X,Z)                      uncleOf                     nephewOf                    brotherOf    304         552 0.021996    0.550725
#                                                    auntOf(X,Y) ∧ boyCousinOf(Y,Z) → auntOf(X,Z)                       auntOf                  boyCousinOf                       auntOf    302         552 0.021851    0.547101
#                                                  nephewOf(X,Y) ∧ auntOf(Y,Z) → boyCousinOf(X,Z)                     nephewOf                       auntOf                  boyCousinOf    302        1044 0.021851    0.289272
#                                    daughterOf(X,Y) ∧ greatGrandfatherOf(Y,Z) → greatAuntOf(X,Z)                   daughterOf           greatGrandfatherOf                  greatAuntOf    297         574 0.021489    0.517422
#                                       grandsonOf(X,Y) ∧ greatGrandmotherOf(Y,Z) → fatherOf(X,Z)                   grandsonOf           greatGrandmotherOf                     fatherOf    295         997 0.021344    0.295888
#                                       grandsonOf(X,Y) ∧ greatGrandfatherOf(Y,Z) → fatherOf(X,Z)                   grandsonOf           greatGrandfatherOf                     fatherOf    295         997 0.021344    0.295888
#                                    grandfatherOf(X,Y) ∧ fatherOf(Y,Z) → greatGrandfatherOf(X,Z)                grandfatherOf                     fatherOf           greatGrandfatherOf    295         295 0.021344    1.000000
#                                    grandmotherOf(X,Y) ∧ fatherOf(Y,Z) → greatGrandmotherOf(X,Z)                grandmotherOf                     fatherOf           greatGrandmotherOf    295         295 0.021344    1.000000
#                                                    brotherOf(X,Y) ∧ uncleOf(Y,Z) → uncleOf(X,Z)                    brotherOf                      uncleOf                      uncleOf    294         495 0.021272    0.593939
#                                    fatherOf(X,Y) ∧ grandfatherOf(Y,Z) → greatGrandfatherOf(X,Z)                     fatherOf                grandfatherOf           greatGrandfatherOf    287         287 0.020766    1.000000
#                                    motherOf(X,Y) ∧ grandfatherOf(Y,Z) → greatGrandmotherOf(X,Z)                     motherOf                grandfatherOf           greatGrandmotherOf    287         287 0.020766    1.000000
#                                          greatGrandsonOf(X,Y) ∧ fatherOf(Y,Z) → grandsonOf(X,Z)              greatGrandsonOf                     fatherOf                   grandsonOf    282         535 0.020404    0.527103
#                                          greatGrandsonOf(X,Y) ∧ motherOf(Y,Z) → grandsonOf(X,Z)              greatGrandsonOf                     motherOf                   grandsonOf    282         535 0.020404    0.527103
#                                       greatGrandfatherOf(X,Y) ∧ grandsonOf(Y,Z) → fatherOf(X,Z)           greatGrandfatherOf                   grandsonOf                     fatherOf    282         854 0.020404    0.330211
#                                       greatGrandmotherOf(X,Y) ∧ grandsonOf(Y,Z) → motherOf(X,Z)           greatGrandmotherOf                   grandsonOf                     motherOf    282         854 0.020404    0.330211
#                                                girlCousinOf(X,Y) ∧ nephewOf(Y,Z) → nieceOf(X,Z)                 girlCousinOf                     nephewOf                      nieceOf    281         505 0.020331    0.556436
#                                                 boyCousinOf(X,Y) ∧ nieceOf(Y,Z) → nephewOf(X,Z)                  boyCousinOf                      nieceOf                     nephewOf    281         507 0.020331    0.554241
#                                      fatherOf(X,Y) ∧ greatAuntOf(Y,Z) → greatGrandfatherOf(X,Z)                     fatherOf                  greatAuntOf           greatGrandfatherOf    278         278 0.020114    1.000000
#                                      motherOf(X,Y) ∧ greatAuntOf(Y,Z) → greatGrandmotherOf(X,Z)                     motherOf                  greatAuntOf           greatGrandmotherOf    278         278 0.020114    1.000000
#                                  daughterOf(X,Y) ∧ greatGrandfatherOf(Y,Z) → grandmotherOf(X,Z)                   daughterOf           greatGrandfatherOf                grandmotherOf    277         574 0.020042    0.482578
#                                     fatherOf(X,Y) ∧ greatGranddaughterOf(Y,Z) → grandsonOf(X,Z)                     fatherOf         greatGranddaughterOf                   grandsonOf    276         544 0.019970    0.507353
#                                             daughterOf(X,Y) ∧ sonOf(Y,Z) → granddaughterOf(X,Z)                   daughterOf                        sonOf              granddaughterOf    273         273 0.019753    1.000000
#                                motherOf(X,Y) ∧ greatGranddaughterOf(Y,Z) → granddaughterOf(X,Z)                     motherOf         greatGranddaughterOf              granddaughterOf    268         544 0.019391    0.492647
#                                                    fatherOf(X,Y) ∧ grandsonOf(Y,Z) → sonOf(X,Z)                     fatherOf                   grandsonOf                        sonOf    266         724 0.019246    0.367403
#                                               fatherOf(X,Y) ∧ granddaughterOf(Y,Z) → sonOf(X,Z)                     fatherOf              granddaughterOf                        sonOf    266         716 0.019246    0.371508
#                                                       sonOf(X,Y) ∧ sonOf(Y,Z) → grandsonOf(X,Z)                        sonOf                        sonOf                   grandsonOf    265         265 0.019174    1.000000
#                                greatGranddaughterOf(X,Y) ∧ fatherOf(Y,Z) → granddaughterOf(X,Z)         greatGranddaughterOf                     fatherOf              granddaughterOf    261         494 0.018884    0.528340
#                                greatGranddaughterOf(X,Y) ∧ motherOf(Y,Z) → granddaughterOf(X,Z)         greatGranddaughterOf                     motherOf              granddaughterOf    261         494 0.018884    0.528340
#                                  greatGrandfatherOf(X,Y) ∧ granddaughterOf(Y,Z) → fatherOf(X,Z)           greatGrandfatherOf              granddaughterOf                     fatherOf    261         856 0.018884    0.304907
#                                  greatGrandmotherOf(X,Y) ∧ granddaughterOf(Y,Z) → motherOf(X,Z)           greatGrandmotherOf              granddaughterOf                     motherOf    261         856 0.018884    0.304907
#                                          motherOf(X,Y) ∧ granddaughterOf(Y,Z) → daughterOf(X,Z)                     motherOf              granddaughterOf                   daughterOf    259         716 0.018740    0.361732
#                                                 nieceOf(X,Y) ∧ uncleOf(Y,Z) → girlCousinOf(X,Z)                      nieceOf                      uncleOf                 girlCousinOf    259         834 0.018740    0.310552
#                                                   nephewOf(X,Y) ∧ uncleOf(Y,Z) → brotherOf(X,Z)                     nephewOf                      uncleOf                    brotherOf    259         680 0.018740    0.380882
#                                                 uncleOf(X,Y) ∧ girlCousinOf(Y,Z) → uncleOf(X,Z)                      uncleOf                 girlCousinOf                      uncleOf    259         476 0.018740    0.544118
#                                                    uncleOf(X,Y) ∧ brotherOf(Y,Z) → uncleOf(X,Z)                      uncleOf                    brotherOf                      uncleOf    259         259 0.018740    1.000000
#                                   granddaughterOf(X,Y) ∧ sonOf(Y,Z) → greatGranddaughterOf(X,Z)              granddaughterOf                        sonOf         greatGranddaughterOf    258         258 0.018667    1.000000
#                                     grandfatherOf(X,Y) ∧ greatGranddaughterOf(Y,Z) → sonOf(X,Z)                grandfatherOf         greatGranddaughterOf                        sonOf    258         856 0.018667    0.301402
#                                    fatherOf(X,Y) ∧ grandmotherOf(Y,Z) → greatGrandfatherOf(X,Z)                     fatherOf                grandmotherOf           greatGrandfatherOf    256         256 0.018523    1.000000
#                                    motherOf(X,Y) ∧ grandmotherOf(Y,Z) → greatGrandmotherOf(X,Z)                     motherOf                grandmotherOf           greatGrandmotherOf    256         256 0.018523    1.000000
#                                                     sisterOf(X,Y) ∧ fatherOf(Y,Z) → auntOf(X,Z)                     sisterOf                     fatherOf                       auntOf    253         253 0.018305    1.000000
#                                                  sonOf(X,Y) ∧ grandmotherOf(Y,Z) → uncleOf(X,Z)                        sonOf                grandmotherOf                      uncleOf    253         506 0.018305    0.500000
#                                                    brotherOf(X,Y) ∧ auntOf(Y,Z) → fatherOf(X,Z)                    brotherOf                       auntOf                     fatherOf    253         653 0.018305    0.387443
#                                    grandmotherOf(X,Y) ∧ motherOf(Y,Z) → greatGrandmotherOf(X,Z)                grandmotherOf                     motherOf           greatGrandmotherOf    252         252 0.018233    1.000000
#                                    grandfatherOf(X,Y) ∧ motherOf(Y,Z) → greatGrandfatherOf(X,Z)                grandfatherOf                     motherOf           greatGrandfatherOf    252         252 0.018233    1.000000
#                                  granddaughterOf(X,Y) ∧ greatGrandfatherOf(Y,Z) → motherOf(X,Z)              granddaughterOf           greatGrandfatherOf                     motherOf    252        1024 0.018233    0.246094
#                                  granddaughterOf(X,Y) ∧ greatGrandmotherOf(Y,Z) → motherOf(X,Z)              granddaughterOf           greatGrandmotherOf                     motherOf    252        1024 0.018233    0.246094
#                                            brotherOf(X,Y) ∧ boyCousinOf(Y,Z) → boyCousinOf(X,Z)                    brotherOf                  boyCousinOf                  boyCousinOf    250         250 0.018088    1.000000
#                                                    motherOf(X,Y) ∧ nieceOf(Y,Z) → sisterOf(X,Z)                     motherOf                      nieceOf                     sisterOf    246         445 0.017799    0.552809
#                                             sonOf(X,Y) ∧ grandsonOf(Y,Z) → greatGrandsonOf(X,Z)                        sonOf                   grandsonOf              greatGrandsonOf    244         244 0.017654    1.000000
#                                       greatAuntOf(X,Y) ∧ greatGrandsonOf(Y,Z) → daughterOf(X,Z)                  greatAuntOf              greatGrandsonOf                   daughterOf    244         484 0.017654    0.504132
#                                                   greatAuntOf(X,Y) ∧ nieceOf(Y,Z) → auntOf(X,Z)                  greatAuntOf                      nieceOf                       auntOf    242         261 0.017510    0.927203
#                                            grandfatherOf(X,Y) ∧ daughterOf(Y,Z) → fatherOf(X,Z)                grandfatherOf                   daughterOf                     fatherOf    240         621 0.017365    0.386473
#                                            grandmotherOf(X,Y) ∧ daughterOf(Y,Z) → motherOf(X,Z)                grandmotherOf                   daughterOf                     motherOf    240         621 0.017365    0.386473
#                                          granddaughterOf(X,Y) ∧ motherOf(Y,Z) → daughterOf(X,Z)              granddaughterOf                     motherOf                   daughterOf    240         792 0.017365    0.303030
#                                          granddaughterOf(X,Y) ∧ fatherOf(Y,Z) → daughterOf(X,Z)              granddaughterOf                     fatherOf                   daughterOf    240         792 0.017365    0.303030
#                                                 motherOf(X,Y) ∧ girlCousinOf(Y,Z) → auntOf(X,Z)                     motherOf                 girlCousinOf                       auntOf    238         394 0.017220    0.604061
#                                               motherOf(X,Y) ∧ grandsonOf(Y,Z) → daughterOf(X,Z)                     motherOf                   grandsonOf                   daughterOf    238         724 0.017220    0.328729
#                                     motherOf(X,Y) ∧ greatGrandsonOf(Y,Z) → granddaughterOf(X,Z)                     motherOf              greatGrandsonOf              granddaughterOf    236         550 0.017075    0.429091
#                                  greatAuntOf(X,Y) ∧ greatGranddaughterOf(Y,Z) → daughterOf(X,Z)                  greatAuntOf         greatGranddaughterOf                   daughterOf    235         428 0.017003    0.549065
# ...
#                       boyFirstCousinOnceRemovedOf(X,Y) ∧ motherOf(Y,Z) → boySecondCousinOf(X,Z)  boyFirstCousinOnceRemovedOf                     motherOf            boySecondCousinOf     31          31 0.002243    1.000000
#                      girlSecondCousinOf(X,Y) ∧ girlFirstCousinOnceRemovedOf(Y,Z) → nieceOf(X,Z)           girlSecondCousinOf girlFirstCousinOnceRemovedOf                      nieceOf     31          65 0.002243    0.476923
#                       boyFirstCousinOnceRemovedOf(X,Y) ∧ fatherOf(Y,Z) → boySecondCousinOf(X,Z)  boyFirstCousinOnceRemovedOf                     fatherOf            boySecondCousinOf     30          30 0.002171    1.000000
#                                     secondUncleOf(X,Y) ∧ boySecondCousinOf(Y,Z) → fatherOf(X,Z)                secondUncleOf            boySecondCousinOf                     fatherOf     30          97 0.002171    0.309278
#                                greatUncleOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → grandfatherOf(X,Z)                 greatUncleOf           girlSecondCousinOf                grandfatherOf     30          52 0.002171    0.576923
#                     boySecondCousinOf(X,Y) ∧ daughterOf(Y,Z) → boyFirstCousinOnceRemovedOf(X,Z)            boySecondCousinOf                   daughterOf  boyFirstCousinOnceRemovedOf     29          59 0.002098    0.491525
#                                boySecondCousinOf(X,Y) ∧ boySecondCousinOf(Y,Z) → brotherOf(X,Z)            boySecondCousinOf            boySecondCousinOf                    brotherOf     29          67 0.002098    0.432836
#                                boySecondCousinOf(X,Y) ∧ brotherOf(Y,Z) → boySecondCousinOf(X,Z)            boySecondCousinOf                    brotherOf            boySecondCousinOf     29          29 0.002098    1.000000
#                    girlSecondCousinOf(X,Y) ∧ boyFirstCousinOnceRemovedOf(Y,Z) → daughterOf(X,Z)           girlSecondCousinOf  boyFirstCousinOnceRemovedOf                   daughterOf     29         123 0.002098    0.235772
#                                girlSecondCousinOf(X,Y) ∧ boySecondCousinOf(Y,Z) → sisterOf(X,Z)           girlSecondCousinOf            boySecondCousinOf                     sisterOf     27          91 0.001954    0.296703
#                         boySecondCousinOf(X,Y) ∧ girlFirstCousinOnceRemovedOf(Y,Z) → sonOf(X,Z)            boySecondCousinOf girlFirstCousinOnceRemovedOf                        sonOf     27         126 0.001954    0.214286
#                                 boySecondCousinOf(X,Y) ∧ sisterOf(Y,Z) → boySecondCousinOf(X,Z)            boySecondCousinOf                     sisterOf            boySecondCousinOf     27          27 0.001954    1.000000
#                        girlSecondCousinOf(X,Y) ∧ sonOf(Y,Z) → girlFirstCousinOnceRemovedOf(X,Z)           girlSecondCousinOf                        sonOf girlFirstCousinOnceRemovedOf     27          59 0.001954    0.457627
#                                  daughterOf(X,Y) ∧ secondUncleOf(Y,Z) → girlSecondCousinOf(X,Z)                   daughterOf                secondUncleOf           girlSecondCousinOf     25          25 0.001809    1.000000
#                                    fatherOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → secondUncleOf(X,Z)                     fatherOf           girlSecondCousinOf                secondUncleOf     25          56 0.001809    0.446429
#                                  greatUncleOf(X,Y) ∧ boySecondCousinOf(Y,Z) → greatUncleOf(X,Z)                 greatUncleOf            boySecondCousinOf                 greatUncleOf     23          68 0.001664    0.338235
#                                  greatAuntOf(X,Y) ∧ boySecondCousinOf(Y,Z) → grandmotherOf(X,Z)                  greatAuntOf            boySecondCousinOf                grandmotherOf     23          55 0.001664    0.418182
#                                    grandsonOf(X,Y) ∧ greatUncleOf(Y,Z) → boySecondCousinOf(X,Z)                   grandsonOf                 greatUncleOf            boySecondCousinOf     22          22 0.001592    1.000000
#                                 grandfatherOf(X,Y) ∧ boySecondCousinOf(Y,Z) → greatUncleOf(X,Z)                grandfatherOf            boySecondCousinOf                 greatUncleOf     22          84 0.001592    0.261905
#                               sisterOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → girlSecondCousinOf(X,Z)                     sisterOf           girlSecondCousinOf           girlSecondCousinOf     22          22 0.001592    1.000000
#  girlSecondCousinOf(X,Y) ∧ boyFirstCousinOnceRemovedOf(Y,Z) → girlFirstCousinOnceRemovedOf(X,Z)           girlSecondCousinOf  boyFirstCousinOnceRemovedOf girlFirstCousinOnceRemovedOf     21         123 0.001519    0.170732
#   boySecondCousinOf(X,Y) ∧ girlFirstCousinOnceRemovedOf(Y,Z) → boyFirstCousinOnceRemovedOf(X,Z)            boySecondCousinOf girlFirstCousinOnceRemovedOf  boyFirstCousinOnceRemovedOf     21         126 0.001519    0.166667
#                                      motherOf(X,Y) ∧ boySecondCousinOf(Y,Z) → secondAuntOf(X,Z)                     motherOf            boySecondCousinOf                 secondAuntOf     19          62 0.001375    0.306452
#                                 greatUncleOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → greatUncleOf(X,Z)                 greatUncleOf           girlSecondCousinOf                 greatUncleOf     19          52 0.001375    0.365385
#                                sisterOf(X,Y) ∧ boySecondCousinOf(Y,Z) → girlSecondCousinOf(X,Z)                     sisterOf            boySecondCousinOf           girlSecondCousinOf     19          19 0.001375    1.000000
#                               brotherOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → boySecondCousinOf(X,Z)                    brotherOf           girlSecondCousinOf            boySecondCousinOf     19          19 0.001375    1.000000
#                                     secondAuntOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → motherOf(X,Z)                 secondAuntOf           girlSecondCousinOf                     motherOf     19          76 0.001375    0.250000
#                     girlFirstCousinOnceRemovedOf(X,Y) ∧ motherOf(Y,Z) → girlSecondCousinOf(X,Z) girlFirstCousinOnceRemovedOf                     motherOf           girlSecondCousinOf     19          19 0.001375    1.000000
#                           girlCousinOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → girlSecondCousinOf(X,Z)                 girlCousinOf           girlSecondCousinOf           girlSecondCousinOf     18          18 0.001302    1.000000
#                  boyFirstCousinOnceRemovedOf(X,Y) ∧ secondUncleOf(Y,Z) → boySecondCousinOf(X,Z)  boyFirstCousinOnceRemovedOf                secondUncleOf            boySecondCousinOf     18         193 0.001302    0.093264
#                                secondUncleOf(X,Y) ∧ boySecondCousinOf(Y,Z) → secondUncleOf(X,Z)                secondUncleOf            boySecondCousinOf                secondUncleOf     18          97 0.001302    0.185567
#                            girlSecondCousinOf(X,Y) ∧ boySecondCousinOf(Y,Z) → girlCousinOf(X,Z)           girlSecondCousinOf            boySecondCousinOf                 girlCousinOf     18          91 0.001302    0.197802
#                             boySecondCousinOf(X,Y) ∧ girlCousinOf(Y,Z) → boySecondCousinOf(X,Z)            boySecondCousinOf                 girlCousinOf            boySecondCousinOf     18          18 0.001302    1.000000
#                                   daughterOf(X,Y) ∧ secondAuntOf(Y,Z) → girlSecondCousinOf(X,Z)                   daughterOf                 secondAuntOf           girlSecondCousinOf     18          18 0.001302    1.000000
#                                 secondAuntOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → secondAuntOf(X,Z)                 secondAuntOf           girlSecondCousinOf                 secondAuntOf     17          76 0.001230    0.223684
#                 girlFirstCousinOnceRemovedOf(X,Y) ∧ secondAuntOf(Y,Z) → girlSecondCousinOf(X,Z) girlFirstCousinOnceRemovedOf                 secondAuntOf           girlSecondCousinOf     17         212 0.001230    0.080189
#                               secondUncleOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → secondUncleOf(X,Z)                secondUncleOf           girlSecondCousinOf                secondUncleOf     16         115 0.001158    0.139130
#                girlFirstCousinOnceRemovedOf(X,Y) ∧ secondUncleOf(Y,Z) → girlSecondCousinOf(X,Z) girlFirstCousinOnceRemovedOf                secondUncleOf           girlSecondCousinOf     16         183 0.001158    0.087432
#                            girlSecondCousinOf(X,Y) ∧ boyCousinOf(Y,Z) → girlSecondCousinOf(X,Z)           girlSecondCousinOf                  boyCousinOf           girlSecondCousinOf     15          15 0.001085    1.000000
#                          boySecondCousinOf(X,Y) ∧ boyFirstCousinOnceRemovedOf(Y,Z) → sonOf(X,Z)            boySecondCousinOf  boyFirstCousinOnceRemovedOf                        sonOf     15          84 0.001085    0.178571
#                             boySecondCousinOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → boyCousinOf(X,Z)            boySecondCousinOf           girlSecondCousinOf                  boyCousinOf     15          95 0.001085    0.157895
#                          boySecondCousinOf(X,Y) ∧ sonOf(Y,Z) → boyFirstCousinOnceRemovedOf(X,Z)            boySecondCousinOf                        sonOf  boyFirstCousinOnceRemovedOf     15          34 0.001085    0.441176
#                   girlSecondCousinOf(X,Y) ∧ daughterOf(Y,Z) → girlFirstCousinOnceRemovedOf(X,Z)           girlSecondCousinOf                   daughterOf girlFirstCousinOnceRemovedOf     14          32 0.001013    0.437500
#                   girlSecondCousinOf(X,Y) ∧ girlFirstCousinOnceRemovedOf(Y,Z) → daughterOf(X,Z)           girlSecondCousinOf girlFirstCousinOnceRemovedOf                   daughterOf     14          65 0.001013    0.215385
#                               girlSecondCousinOf(X,Y) ∧ sisterOf(Y,Z) → girlSecondCousinOf(X,Z)           girlSecondCousinOf                     sisterOf           girlSecondCousinOf     14          14 0.001013    1.000000
#                               girlSecondCousinOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → sisterOf(X,Z)           girlSecondCousinOf           girlSecondCousinOf                     sisterOf     14          49 0.001013    0.285714
# girlSecondCousinOf(X,Y) ∧ girlFirstCousinOnceRemovedOf(Y,Z) → girlFirstCousinOnceRemovedOf(X,Z)           girlSecondCousinOf girlFirstCousinOnceRemovedOf girlFirstCousinOnceRemovedOf     12          65 0.000868    0.184615
#                                         sonOf(X,Y) ∧ secondAuntOf(Y,Z) → boySecondCousinOf(X,Z)                        sonOf                 secondAuntOf            boySecondCousinOf     11          11 0.000796    1.000000
#                                  secondAuntOf(X,Y) ∧ boySecondCousinOf(Y,Z) → secondAuntOf(X,Z)                 secondAuntOf            boySecondCousinOf                 secondAuntOf     11         110 0.000796    0.100000
#                           girlSecondCousinOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → girlCousinOf(X,Z)           girlSecondCousinOf           girlSecondCousinOf                 girlCousinOf     11          49 0.000796    0.224490
#                             boyCousinOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → boySecondCousinOf(X,Z)                  boyCousinOf           girlSecondCousinOf            boySecondCousinOf     11          11 0.000796    1.000000
#                   boyFirstCousinOnceRemovedOf(X,Y) ∧ secondAuntOf(Y,Z) → boySecondCousinOf(X,Z)  boyFirstCousinOnceRemovedOf                 secondAuntOf            boySecondCousinOf     11         239 0.000796    0.046025
#                            girlCousinOf(X,Y) ∧ boySecondCousinOf(Y,Z) → girlSecondCousinOf(X,Z)                 girlCousinOf            boySecondCousinOf           girlSecondCousinOf     11          11 0.000796    1.000000
#                           girlSecondCousinOf(X,Y) ∧ girlCousinOf(Y,Z) → girlSecondCousinOf(X,Z)           girlSecondCousinOf                 girlCousinOf           girlSecondCousinOf     11          11 0.000796    1.000000
#                              boyCousinOf(X,Y) ∧ boySecondCousinOf(Y,Z) → boySecondCousinOf(X,Z)                  boyCousinOf            boySecondCousinOf            boySecondCousinOf     10          10 0.000724    1.000000
#                               granddaughterOf(X,Y) ∧ greatAuntOf(Y,Z) → girlSecondCousinOf(X,Z)              granddaughterOf                  greatAuntOf           girlSecondCousinOf      9           9 0.000651    1.000000
#                                 grandmotherOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → greatAuntOf(X,Z)                grandmotherOf           girlSecondCousinOf                  greatAuntOf      9          70 0.000651    0.128571
#    boySecondCousinOf(X,Y) ∧ boyFirstCousinOnceRemovedOf(Y,Z) → boyFirstCousinOnceRemovedOf(X,Z)            boySecondCousinOf  boyFirstCousinOnceRemovedOf  boyFirstCousinOnceRemovedOf      8          84 0.000579    0.095238
#                      girlSecondCousinOf(X,Y) ∧ boySecondCousinOf(Y,Z) → girlSecondCousinOf(X,Z)           girlSecondCousinOf            boySecondCousinOf           girlSecondCousinOf      6          91 0.000434    0.065934
#                       boySecondCousinOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → boySecondCousinOf(X,Z)            boySecondCousinOf           girlSecondCousinOf            boySecondCousinOf      6          95 0.000434    0.063158
#                              boySecondCousinOf(X,Y) ∧ boyCousinOf(Y,Z) → boySecondCousinOf(X,Z)            boySecondCousinOf                  boyCousinOf            boySecondCousinOf      6           6 0.000434    1.000000
#                              boySecondCousinOf(X,Y) ∧ boySecondCousinOf(Y,Z) → boyCousinOf(X,Z)            boySecondCousinOf            boySecondCousinOf                  boyCousinOf      6          67 0.000434    0.089552
#                        boySecondCousinOf(X,Y) ∧ boySecondCousinOf(Y,Z) → boySecondCousinOf(X,Z)            boySecondCousinOf            boySecondCousinOf            boySecondCousinOf      4          67 0.000289    0.059701
#                     girlSecondCousinOf(X,Y) ∧ girlSecondCousinOf(Y,Z) → girlSecondCousinOf(X,Z)           girlSecondCousinOf           girlSecondCousinOf           girlSecondCousinOf      2          49 0.000145    0.040816
#
# ================================================================================
# Examples for top 3 rules:
# ================================================================================
#
# Rule: sisterOf(X,Y) ∧ granddaughterOf(Y,Z) → granddaughterOf(X,Z)
# Confidence: 100.00%, Count: 772
#       X        Y       Z  sisterOf(X,Y)  granddaughterOf(Y,Z)  granddaughterOf(X,Z)
# olivia0 selina10  ella19           True                  True                  True
# olivia0 selina10 david20           True                  True                  True
# olivia0 selina10   emma7           True                  True                  True
# --------------------------------------------------------------------------------
#
# Rule: granddaughterOf(X,Y) ∧ grandmotherOf(Y,Z) → sisterOf(X,Z)
# Confidence: 46.75%, Count: 747
#       X      Y          Z  granddaughterOf(X,Y)  grandmotherOf(Y,Z)  sisterOf(X,Z)
# olivia0 ella19   selina10                  True                True           True
# olivia0 ella19 isabella11                  True                True           True
# olivia0 ella19    oskar24                  True                True           True
# --------------------------------------------------------------------------------
#
# Rule: grandfatherOf(X,Y) ∧ sisterOf(Y,Z) → grandfatherOf(X,Z)
# Confidence: 100.00%, Count: 747
#        X       Y        Z  grandfatherOf(X,Y)  sisterOf(Y,Z)  grandfatherOf(X,Z)
# dominik2   lisa5    nico4                True           True                True
# dominik2   lisa5   elias6                True           True                True
#  david20 olivia0 selina10                True           True                True
# --------------------------------------------------------------------------------

# %%
import pandas as pd
from collections import defaultdict
from tqdm import tqdm

# Step 1: Parse the graph data
def parse_graph(file_path):
    """Parse the graph file and return a list of triples (subject, relation, object)"""
    triples = []
    with open(file_path, 'r') as f:
        for line in f:
            line = line.strip()
            if line:
                parts = line.split()
                if len(parts) == 3:
                    subject, relation, obj = parts
                    triples.append((subject, relation, obj))
    return triples

# Step 2: Build optimized data structures
def build_graph_structures(triples):
    """Build optimized data structures for fast querying"""
    # outgoing[node] = list of (relation, target) pairs
    outgoing = defaultdict(list)
    # relation_index[(relation, source)] = list of targets
    relation_index = defaultdict(list)
    # pair_to_relations[(source, target)] = set of relations
    pair_to_relations = defaultdict(set)
    
    persons = set()
    relations = set()
    
    for subject, relation, obj in triples:
        outgoing[subject].append((relation, obj))
        relation_index[(relation, subject)].append(obj)
        pair_to_relations[(subject, obj)].add(relation)
        persons.add(subject)
        persons.add(obj)
        relations.add(relation)
    
    return outgoing, relation_index, pair_to_relations, persons, relations

# Step 3: Optimized mining for length 2
def mine_length_2_optimized(triples, outgoing, pair_to_relations, min_support=2):
    """
    Optimized: relation1(X,Y) ∧ relation2(Y,Z) → relation3(X,Z)
    """
    body_counts = defaultdict(int)
    rule_counts = defaultdict(int)
    
    # Group triples by middle node Y for efficient joining
    for x, rel1, y in triples:
        if y not in outgoing:
            continue
            
        for rel2, z in outgoing[y]:
            body_counts[(rel1, rel2)] += 1
            
            # Check if (x, z) has any relations
            if (x, z) in pair_to_relations:
                for rel3 in pair_to_relations[(x, z)]:
                    rule_counts[(rel1, rel2, rel3)] += 1
    
    # Filter by minimum support
    rule_counts = {k: v for k, v in rule_counts.items() if v >= min_support}
    
    return rule_counts, body_counts

# Step 4: Optimized mining for length 3
def mine_length_3_optimized(triples, outgoing, pair_to_relations, min_support=2):
    """
    Optimized: relation1(X,Y) ∧ relation2(Y,Z) ∧ relation3(Z,W) → relation4(X,W)
    """
    body_counts = defaultdict(int)
    rule_counts = defaultdict(int)
    
    # Build 2-hop paths first: (X, rel1, rel2) -> list of (Y, Z) pairs
    two_hop_paths = defaultdict(list)
    
    for x, rel1, y in triples:
        if y in outgoing:
            for rel2, z in outgoing[y]:
                two_hop_paths[(x, rel1, rel2)].append((y, z))
    
    # Extend to 3-hop
    for (x, rel1, rel2), yz_pairs in two_hop_paths.items():
        for y, z in yz_pairs:
            if z not in outgoing:
                continue
                
            for rel3, w in outgoing[z]:
                body_counts[(rel1, rel2, rel3)] += 1
                
                if (x, w) in pair_to_relations:
                    for rel4 in pair_to_relations[(x, w)]:
                        rule_counts[(rel1, rel2, rel3, rel4)] += 1
    
    rule_counts = {k: v for k, v in rule_counts.items() if v >= min_support}
    
    return rule_counts, body_counts

# Step 5: Optimized mining for length 4
def mine_length_4_optimized(triples, outgoing, pair_to_relations, min_support=2):
    """
    Optimized: relation1(X,Y) ∧ relation2(Y,Z) ∧ relation3(Z,W) ∧ relation4(W,V) → relation5(X,V)
    """
    body_counts = defaultdict(int)
    rule_counts = defaultdict(int)
    
    # Build 3-hop paths first
    three_hop_paths = defaultdict(list)
    
    for x, rel1, y in triples:
        if y not in outgoing:
            continue
        for rel2, z in outgoing[y]:
            if z not in outgoing:
                continue
            for rel3, w in outgoing[z]:
                three_hop_paths[(x, rel1, rel2, rel3)].append(w)
    
    # Extend to 4-hop
    for (x, rel1, rel2, rel3), w_list in three_hop_paths.items():
        for w in w_list:
            if w not in outgoing:
                continue
                
            for rel4, v in outgoing[w]:
                body_counts[(rel1, rel2, rel3, rel4)] += 1
                
                if (x, v) in pair_to_relations:
                    for rel5 in pair_to_relations[(x, v)]:
                        rule_counts[(rel1, rel2, rel3, rel4, rel5)] += 1
    
    rule_counts = {k: v for k, v in rule_counts.items() if v >= min_support}
    
    return rule_counts, body_counts

# Step 6: Calculate metrics
def calculate_metrics(rule_counts, body_counts, total_triples, chain_length):
    """Calculate support and confidence"""
    results = []
    
    for rule_tuple, count in rule_counts.items():
        body_tuple = rule_tuple[:-1]
        head_relation = rule_tuple[-1]
        body_count = body_counts.get(body_tuple, 0)
        
        if body_count == 0:
            continue
        
        support = count / total_triples
        confidence = count / body_count
        
        # Build rule string
        variables = ['X', 'Y', 'Z', 'W', 'V', 'U'][:chain_length + 1]
        body_parts = [f'{rel}({variables[i]},{variables[i+1]})' 
                      for i, rel in enumerate(body_tuple)]
        body_str = ' ∧ '.join(body_parts)
        head_str = f'{head_relation}({variables[0]},{variables[chain_length]})'
        rule_str = f'{body_str} → {head_str}'
        
        results.append({
            'Rule': rule_str,
            'Body_Relations': ' -> '.join(body_tuple),
            'Head_Relation': head_relation,
            'Count': count,
            'Body_Count': body_count,
            'Support': support,
            'Confidence': confidence,
            'Chain_Length': chain_length
        })
    
    return pd.DataFrame(results).sort_values(['Confidence', 'Count'], ascending=[False, False])

# Step 7: Find examples (optimized)
def find_examples_fast(triples, outgoing, rule_tuple, max_examples=3):
    """Fast example finding"""
    body_rels = rule_tuple[:-1]
    head_rel = rule_tuple[-1]
    chain_length = len(body_rels)
    
    examples = []
    variables = ['X', 'Y', 'Z', 'W', 'V', 'U'][:chain_length + 1]
    
    # Build pair_to_relations for quick lookup
    pair_to_relations = defaultdict(set)
    for s, r, o in triples:
        pair_to_relations[(s, o)].add(r)
    
    for x, rel1, y in triples:
        if rel1 != body_rels[0]:
            continue
        
        # Try to build the chain
        current_nodes = [y]
        chain_nodes = [x, y]
        
        valid = True
        for i in range(1, chain_length):
            found = False
            for node in current_nodes:
                if node in outgoing:
                    for rel, next_node in outgoing[node]:
                        if rel == body_rels[i]:
                            chain_nodes.append(next_node)
                            current_nodes = [next_node]
                            found = True
                            break
                if found:
                    break
            if not found:
                valid = False
                break
        
        if not valid or len(chain_nodes) != chain_length + 1:
            continue
        
        # Check if head holds
        if (x, chain_nodes[-1]) in pair_to_relations and head_rel in pair_to_relations[(x, chain_nodes[-1])]:
            example = {}
            for i, var in enumerate(variables):
                example[var] = chain_nodes[i]
            
            for i, rel in enumerate(body_rels):
                example[f'{rel}({variables[i]},{variables[i+1]})'] = '✓'
            example[f'{head_rel}({variables[0]},{variables[chain_length]})'] = '✓'
            
            examples.append(example)
            
            if len(examples) >= max_examples:
                break
    
    return pd.DataFrame(examples)

# Main execution
print("Loading graph...")
file_path = 'train.txt'  # Change this to your file path
triples = parse_graph(file_path)

print("Building indexes...")
outgoing, relation_index, pair_to_relations, persons, relations = build_graph_structures(triples)

total_triples = len(triples)
print(f"\nGraph Statistics:")
print(f"  Total triples: {total_triples}")
print(f"  Unique persons: {len(persons)}")
print(f"  Unique relations: {len(relations)}")

# Set minimum support threshold
MIN_SUPPORT = 2
MIN_CONFIDENCE = 0.1  # 10%

# Mine different chain lengths
for chain_len, mine_func in [(2, mine_length_2_optimized), 
                              (3, mine_length_3_optimized),
                              (4, mine_length_4_optimized)]:
    
    print(f"\n{'='*100}")
    print(f"Mining Chain Length {chain_len} (min_support={MIN_SUPPORT})...")
    print(f"{'='*100}")
    
    rule_counts, body_counts = mine_func(triples, outgoing, pair_to_relations, MIN_SUPPORT)
    
    if not rule_counts:
        print(f"No rules found with minimum support of {MIN_SUPPORT}")
        continue
    
    results_df = calculate_metrics(rule_counts, body_counts, total_triples, chain_len)
    
    # Filter by confidence
    results_df = results_df[results_df['Confidence'] >= MIN_CONFIDENCE]
    
    print(f"\nFound {len(results_df)} rules")
    print(f"\nTop 10 rules:")
    print(results_df.head(10)[['Rule', 'Count', 'Body_Count', 'Confidence']].to_string(index=False))
    
    # Save to CSV
    csv_filename = f'horn_rules_length_{chain_len}.csv'
    results_df.to_csv(csv_filename, index=False)
    print(f"\nSaved to {csv_filename}")
    
    # Show examples for top 3
    print(f"\nTop 3 Rule Examples:")
    print("-" * 100)
    for idx, row in results_df.head(3).iterrows():
        print(f"\n{row['Rule']}")
        print(f"Confidence: {row['Confidence']:.1%} | Count: {row['Count']} | Body: {row['Body_Count']}")
        
        body_rels = tuple(row['Body_Relations'].split(' -> '))
        rule_tuple = body_rels + (row['Head_Relation'],)
        
        examples = find_examples_fast(triples, outgoing, rule_tuple, max_examples=2)
        if not examples.empty:
            print(examples.to_string(index=False))
        print("-" * 100)

print("\n" + "="*100)
print("Mining complete!")
print("="*100)
# Out:
# Loading graph...
# Building indexes...
#
# Graph Statistics:
#   Total triples: 13821
#   Unique persons: 1316
#   Unique relations: 28
#
# ====================================================================================================
# Mining Chain Length 2 (min_support=2)...
# ====================================================================================================
#
# Found 614 rules
#
# Top 10 rules:
#                                                        Rule  Count  Body_Count  Confidence
# sisterOf(X,Y) ∧ granddaughterOf(Y,Z) → granddaughterOf(X,Z)    772         772         1.0
#     grandmotherOf(X,Y) ∧ sisterOf(Y,Z) → grandmotherOf(X,Z)    747         747         1.0
#     grandfatherOf(X,Y) ∧ sisterOf(Y,Z) → grandfatherOf(X,Z)    747         747         1.0
#      sisterOf(X,Y) ∧ grandsonOf(Y,Z) → granddaughterOf(X,Z)    722         722         1.0
#     brotherOf(X,Y) ∧ granddaughterOf(Y,Z) → grandsonOf(X,Z)    722         722         1.0
#    grandmotherOf(X,Y) ∧ brotherOf(Y,Z) → grandmotherOf(X,Z)    673         673         1.0
#    grandfatherOf(X,Y) ∧ brotherOf(Y,Z) → grandfatherOf(X,Z)    673         673         1.0
#          brotherOf(X,Y) ∧ grandsonOf(Y,Z) → grandsonOf(X,Z)    624         624         1.0
# nephewOf(X,Y) ∧ granddaughterOf(Y,Z) → greatGrandsonOf(X,Z)    608         608         1.0
#  grandmotherOf(X,Y) ∧ auntOf(Y,Z) → greatGrandmotherOf(X,Z)    562         562         1.0
#
# Saved to horn_rules_length_2.csv
#
# Top 3 Rule Examples:
# ----------------------------------------------------------------------------------------------------
#
# sisterOf(X,Y) ∧ granddaughterOf(Y,Z) → granddaughterOf(X,Z)
# Confidence: 100.0% | Count: 772 | Body: 772
#       X          Y      Z sisterOf(X,Y) granddaughterOf(Y,Z) granddaughterOf(X,Z)
# olivia0   selina10 ella19             ✓                    ✓                    ✓
# olivia0 isabella11 ella19             ✓                    ✓                    ✓
# ----------------------------------------------------------------------------------------------------
#
# grandmotherOf(X,Y) ∧ sisterOf(Y,Z) → grandmotherOf(X,Z)
# Confidence: 100.0% | Count: 747 | Body: 747
#          X       Y        Z grandmotherOf(X,Y) sisterOf(Y,Z) grandmotherOf(X,Z)
# katharina1   lisa5    nico4                  ✓             ✓                  ✓
#     ella19 olivia0 selina10                  ✓             ✓                  ✓
# ----------------------------------------------------------------------------------------------------
#
# grandfatherOf(X,Y) ∧ sisterOf(Y,Z) → grandfatherOf(X,Z)
# Confidence: 100.0% | Count: 747 | Body: 747
#        X       Y        Z grandfatherOf(X,Y) sisterOf(Y,Z) grandfatherOf(X,Z)
# dominik2   lisa5    nico4                  ✓             ✓                  ✓
#  david20 olivia0 selina10                  ✓             ✓                  ✓
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# Mining Chain Length 3 (min_support=2)...
# ====================================================================================================
#
# Found 13521 rules
#
# Top 10 rules:
#                                                                                          Rule  Count  Body_Count  Confidence
#                   sisterOf(X,Y) ∧ sisterOf(Y,Z) ∧ granddaughterOf(Z,W) → granddaughterOf(X,W)   1492        1492         1.0
#                  sisterOf(X,Y) ∧ brotherOf(Y,Z) ∧ granddaughterOf(Z,W) → granddaughterOf(X,W)   1458        1458         1.0
#                            brotherOf(X,Y) ∧ sisterOf(Y,Z) ∧ grandsonOf(Z,W) → grandsonOf(X,W)   1254        1254         1.0
#                 daughterOf(X,Y) ∧ fatherOf(Y,Z) ∧ granddaughterOf(Z,W) → granddaughterOf(X,W)   1138        1138         1.0
#                           brotherOf(X,Y) ∧ brotherOf(Y,Z) ∧ grandsonOf(Z,W) → grandsonOf(X,W)   1116        1116         1.0
#                       grandmotherOf(X,Y) ∧ sisterOf(Y,Z) ∧ sisterOf(Z,W) → grandmotherOf(X,W)   1114        1114         1.0
#                       grandfatherOf(X,Y) ∧ sisterOf(Y,Z) ∧ sisterOf(Z,W) → grandfatherOf(X,W)   1114        1114         1.0
# girlCousinOf(X,Y) ∧ girlCousinOf(Y,Z) ∧ greatGranddaughterOf(Z,W) → greatGranddaughterOf(X,W)   1056        1056         1.0
#                                sonOf(X,Y) ∧ fatherOf(Y,Z) ∧ grandsonOf(Z,W) → grandsonOf(X,W)   1054        1054         1.0
#                      grandmotherOf(X,Y) ∧ brotherOf(Y,Z) ∧ sisterOf(Z,W) → grandmotherOf(X,W)    995         995         1.0
#
# Saved to horn_rules_length_3.csv
#
# Top 3 Rule Examples:
# ----------------------------------------------------------------------------------------------------
#
# sisterOf(X,Y) ∧ sisterOf(Y,Z) ∧ granddaughterOf(Z,W) → granddaughterOf(X,W)
# Confidence: 100.0% | Count: 1492 | Body: 1492
#       X          Y       Z      W sisterOf(X,Y) sisterOf(Y,Z) granddaughterOf(Z,W) granddaughterOf(X,W)
# olivia0   selina10 olivia0 ella19             ✓             ✓                    ✓                    ✓
# olivia0 isabella11 olivia0 ella19             ✓             ✓                    ✓                    ✓
# ----------------------------------------------------------------------------------------------------
#
# sisterOf(X,Y) ∧ brotherOf(Y,Z) ∧ granddaughterOf(Z,W) → granddaughterOf(X,W)
# Confidence: 100.0% | Count: 1458 | Body: 1458
#       X       Y       Z      W sisterOf(X,Y) brotherOf(Y,Z) granddaughterOf(Z,W) granddaughterOf(X,W)
# olivia0 oskar24 olivia0 ella19             ✓              ✓                    ✓                    ✓
# olivia0   adam9 olivia0 ella19             ✓              ✓                    ✓                    ✓
# ----------------------------------------------------------------------------------------------------
#
# brotherOf(X,Y) ∧ sisterOf(Y,Z) ∧ grandsonOf(Z,W) → grandsonOf(X,W)
# Confidence: 100.0% | Count: 1254 | Body: 1254
#       X         Y       Z          W brotherOf(X,Y) sisterOf(Y,Z) grandsonOf(Z,W) grandsonOf(X,W)
# jonas23 johanna22 jonas23      emma7              ✓             ✓               ✓               ✓
#   nico4     lisa5   nico4 katharina1              ✓             ✓               ✓               ✓
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# Mining Chain Length 4 (min_support=2)...
# ====================================================================================================
#
# Found 246746 rules
#
# Top 10 rules:
#                                                                                                                        Rule  Count  Body_Count  Confidence
#                                 sisterOf(X,Y) ∧ sisterOf(Y,Z) ∧ sisterOf(Z,W) ∧ granddaughterOf(W,V) → granddaughterOf(X,V)   3316        3316         1.0
# sisterOf(X,Y) ∧ greatGranddaughterOf(Y,Z) ∧ greatGrandfatherOf(Z,W) ∧ greatGranddaughterOf(W,V) → greatGranddaughterOf(X,V)   3260        3260         1.0
# sisterOf(X,Y) ∧ greatGranddaughterOf(Y,Z) ∧ greatGrandmotherOf(Z,W) ∧ greatGranddaughterOf(W,V) → greatGranddaughterOf(X,V)   3260        3260         1.0
#                                nieceOf(X,Y) ∧ auntOf(Y,Z) ∧ nieceOf(Z,W) ∧ granddaughterOf(W,V) → greatGranddaughterOf(X,V)   2688        2688         1.0
#           sisterOf(X,Y) ∧ granddaughterOf(Y,Z) ∧ grandfatherOf(Z,W) ∧ greatGranddaughterOf(W,V) → greatGranddaughterOf(X,V)   2608        2608         1.0
#           sisterOf(X,Y) ∧ granddaughterOf(Y,Z) ∧ grandmotherOf(Z,W) ∧ greatGranddaughterOf(W,V) → greatGranddaughterOf(X,V)   2608        2608         1.0
#                                     sisterOf(X,Y) ∧ brotherOf(Y,Z) ∧ sisterOf(Z,W) ∧ grandsonOf(W,V) → granddaughterOf(X,V)   2486        2486         1.0
#                                    brotherOf(X,Y) ∧ sisterOf(Y,Z) ∧ brotherOf(Z,W) ∧ granddaughterOf(W,V) → grandsonOf(X,V)   2486        2486         1.0
#                                        brotherOf(X,Y) ∧ brotherOf(Y,Z) ∧ brotherOf(Z,W) ∧ grandsonOf(W,V) → grandsonOf(X,V)   2340        2340         1.0
#                                     grandmotherOf(X,Y) ∧ sisterOf(Y,Z) ∧ sisterOf(Z,W) ∧ sisterOf(W,V) → grandmotherOf(X,V)   2314        2314         1.0
#
# Saved to horn_rules_length_4.csv
#
# Top 3 Rule Examples:
# ----------------------------------------------------------------------------------------------------
#
# sisterOf(X,Y) ∧ sisterOf(Y,Z) ∧ sisterOf(Z,W) ∧ granddaughterOf(W,V) → granddaughterOf(X,V)
# Confidence: 100.0% | Count: 3316 | Body: 3316
#       X          Y       Z        W      V sisterOf(X,Y) sisterOf(Y,Z) sisterOf(Z,W) granddaughterOf(W,V) granddaughterOf(X,V)
# olivia0   selina10 olivia0 selina10 ella19             ✓             ✓             ✓                    ✓                    ✓
# olivia0 isabella11 olivia0 selina10 ella19             ✓             ✓             ✓                    ✓                    ✓
# ----------------------------------------------------------------------------------------------------
#
# sisterOf(X,Y) ∧ greatGranddaughterOf(Y,Z) ∧ greatGrandfatherOf(Z,W) ∧ greatGranddaughterOf(W,V) → greatGranddaughterOf(X,V)
# Confidence: 100.0% | Count: 3260 | Body: 3260
#         X         Y        Z         W        V sisterOf(X,Y) greatGranddaughterOf(Y,Z) greatGrandfatherOf(Z,W) greatGranddaughterOf(W,V) greatGranddaughterOf(X,V)
# marlene40   marie43 tobias37 marlene40 tobias37             ✓                         ✓                       ✓                         ✓                         ✓
#   marie43 marlene40 tobias37 marlene40 tobias37             ✓                         ✓                       ✓                         ✓                         ✓
# ----------------------------------------------------------------------------------------------------
#
# sisterOf(X,Y) ∧ greatGranddaughterOf(Y,Z) ∧ greatGrandmotherOf(Z,W) ∧ greatGranddaughterOf(W,V) → greatGranddaughterOf(X,V)
# Confidence: 100.0% | Count: 3260 | Body: 3260
#         X         Y            Z        W            V sisterOf(X,Y) greatGranddaughterOf(Y,Z) greatGrandmotherOf(Z,W) greatGranddaughterOf(W,V) greatGranddaughterOf(X,V)
#  alina123 emilia130 anastasia106 alina123 anastasia106             ✓                         ✓                       ✓                         ✓                         ✓
# emilia130  alina123 anastasia106 alina123 anastasia106             ✓                         ✓                       ✓                         ✓                         ✓
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# Mining complete!
# ====================================================================================================

# %% [markdown]
# ## Mining the Triangle RuleS (A<-B->C)=>(A<->C) and (A->B<-C)=>(A<->C)

# %%
import pandas as pd
from collections import defaultdict

# Step 1: Parse the graph data
def parse_graph(file_path):
    """Parse the graph file and return a list of triples (subject, relation, object)"""
    triples = []
    with open(file_path, 'r') as f:
        for line in f:
            line = line.strip()
            if line:
                parts = line.split()
                if len(parts) == 3:
                    subject, relation, obj = parts
                    triples.append((subject, relation, obj))
    return triples

# Step 2: Build data structures
def build_graph_structures(triples):
    """Build data structures for efficient querying"""
    # outgoing[node] = list of (relation, target) pairs
    outgoing = defaultdict(list)
    # incoming[node] = list of (relation, source) pairs  
    incoming = defaultdict(list)
    # pair_to_relations[(source, target)] = set of relations
    pair_to_relations = defaultdict(set)
    
    persons = set()
    relations = set()
    
    for subject, relation, obj in triples:
        outgoing[subject].append((relation, obj))
        incoming[obj].append((relation, subject))
        pair_to_relations[(subject, obj)].add(relation)
        persons.add(subject)
        persons.add(obj)
        relations.add(relation)
    
    return outgoing, incoming, pair_to_relations, persons, relations

# Step 3: Mine Triangle Closure Type 1: A←B→C ⇒ A↔C
def mine_triangle_closure_type1(triples, outgoing, incoming, pair_to_relations, min_support=2):
    """
    Mine rules: relation1(B,A) ∧ relation2(B,C) → relation3(A,C)
    Triangle closure pattern: A←B→C ⇒ A↔C
    
    This means:
    - If B has relation1 to A (B→A)
    - And B has relation2 to C (B→C)  
    - Then A should have relation3 to C (A→C or A↔C)
    """
    
    # Counters
    body_counts = defaultdict(int)  # (rel1, rel2) -> count
    rule_counts = defaultdict(int)  # (rel1, rel2, rel3) -> count
    bidirectional_body_counts = defaultdict(int)  # (rel1, rel2) -> count where A↔C exists
    bidirectional_rule_counts = defaultdict(int)  # (rel1, rel2, rel3, rel4) -> count for A→C and C→A
    
    # For each node B (the central node in the triangle)
    for b in outgoing:
        # Get all nodes that B points to
        b_outgoing = outgoing[b]
        
        # For each pair of nodes that B points to
        for i, (rel1, a) in enumerate(b_outgoing):
            for j, (rel2, c) in enumerate(b_outgoing):
                if i >= j or a == c:  # Skip same pairs and avoid duplicates
                    continue
                
                # We have: B→A (rel1) and B→C (rel2)
                # This is the pattern: A←B→C
                body_counts[(rel1, rel2)] += 1
                
                # Check if A→C exists (any relation)
                if (a, c) in pair_to_relations:
                    for rel3 in pair_to_relations[(a, c)]:
                        rule_counts[(rel1, rel2, rel3)] += 1
                
                # Check if C→A exists (any relation)
                if (c, a) in pair_to_relations:
                    for rel3 in pair_to_relations[(c, a)]:
                        rule_counts[(rel2, rel1, rel3)] += 1  # Note: flipped order
                
                # Check for bidirectional closure: A↔C (both A→C and C→A exist)
                if (a, c) in pair_to_relations and (c, a) in pair_to_relations:
                    bidirectional_body_counts[(rel1, rel2)] += 1
                    
                    for rel_ac in pair_to_relations[(a, c)]:
                        for rel_ca in pair_to_relations[(c, a)]:
                            bidirectional_rule_counts[(rel1, rel2, rel_ac, rel_ca)] += 1
    
    # Filter by minimum support
    rule_counts = {k: v for k, v in rule_counts.items() if v >= min_support}
    bidirectional_rule_counts = {k: v for k, v in bidirectional_rule_counts.items() if v >= min_support}
    
    return rule_counts, body_counts, bidirectional_rule_counts, bidirectional_body_counts

# Step 4: Mine Triangle Closure Type 2: A→B←C ⇒ A↔C
def mine_triangle_closure_type2(triples, outgoing, incoming, pair_to_relations, min_support=2):
    """
    Mine rules: relation1(A,B) ∧ relation2(C,B) → relation3(A,C)
    Triangle closure pattern: A→B←C ⇒ A↔C
    
    This means:
    - If A has relation1 to B (A→B)
    - And C has relation2 to B (C→B)  
    - Then A should have relation3 to C (A→C or A↔C)
    """
    
    # Counters
    body_counts = defaultdict(int)  # (rel1, rel2) -> count
    rule_counts = defaultdict(int)  # (rel1, rel2, rel3) -> count
    bidirectional_body_counts = defaultdict(int)  # (rel1, rel2) -> count where A↔C exists
    bidirectional_rule_counts = defaultdict(int)  # (rel1, rel2, rel3, rel4) -> count for A→C and C→A
    
    # For each node B (the central node in the triangle)
    for b in incoming:
        # Get all nodes that point to B
        b_incoming = incoming[b]
        
        # For each pair of nodes that point to B
        for i, (rel1, a) in enumerate(b_incoming):
            for j, (rel2, c) in enumerate(b_incoming):
                if i >= j or a == c:  # Skip same pairs and avoid duplicates
                    continue
                
                # We have: A→B (rel1) and C→B (rel2)
                # This is the pattern: A→B←C
                body_counts[(rel1, rel2)] += 1
                
                # Check if A→C exists (any relation)
                if (a, c) in pair_to_relations:
                    for rel3 in pair_to_relations[(a, c)]:
                        rule_counts[(rel1, rel2, rel3)] += 1
                
                # Check if C→A exists (any relation)
                if (c, a) in pair_to_relations:
                    for rel3 in pair_to_relations[(c, a)]:
                        rule_counts[(rel2, rel1, rel3)] += 1  # Note: flipped order
                
                # Check for bidirectional closure: A↔C (both A→C and C→A exist)
                if (a, c) in pair_to_relations and (c, a) in pair_to_relations:
                    bidirectional_body_counts[(rel1, rel2)] += 1
                    
                    for rel_ac in pair_to_relations[(a, c)]:
                        for rel_ca in pair_to_relations[(c, a)]:
                            bidirectional_rule_counts[(rel1, rel2, rel_ac, rel_ca)] += 1
    
    # Filter by minimum support
    rule_counts = {k: v for k, v in rule_counts.items() if v >= min_support}
    bidirectional_rule_counts = {k: v for k, v in bidirectional_rule_counts.items() if v >= min_support}
    
    return rule_counts, body_counts, bidirectional_rule_counts, bidirectional_body_counts

# Step 5: Calculate metrics for triangle closure
def calculate_triangle_metrics(rule_counts, body_counts, total_triples, pattern_type):
    """Calculate metrics for triangle closure rules"""
    results = []
    
    for (rel1, rel2, rel3), count in rule_counts.items():
        body_count = body_counts.get((rel1, rel2), 0)
        
        if body_count == 0:
            continue
        
        support = count / total_triples
        confidence = count / body_count
        
        # Build rule string based on pattern type
        if pattern_type == "type1":
            rule_str = f'{rel1}(B,A) ∧ {rel2}(B,C) → {rel3}(A,C)'
            pattern_str = f'A←[{rel1}]B→[{rel2}]C ⇒ A→[{rel3}]C'
        else:  # type2
            rule_str = f'{rel1}(A,B) ∧ {rel2}(C,B) → {rel3}(A,C)'
            pattern_str = f'A→[{rel1}]B←[{rel2}]C ⇒ A→[{rel3}]C'
        
        results.append({
            'Rule': rule_str,
            'Pattern': pattern_str,
            'Relation1': rel1,
            'Relation2': rel2,
            'Relation3': rel3,
            'Count': count,
            'Body_Count': body_count,
            'Support': support,
            'Confidence': confidence
        })
    
    return pd.DataFrame(results).sort_values(['Confidence', 'Count'], ascending=[False, False])

# Step 6: Calculate metrics for bidirectional closure
def calculate_bidirectional_metrics(bidirectional_rule_counts, bidirectional_body_counts, total_triples, pattern_type):
    """Calculate metrics for bidirectional triangle closure A↔C"""
    results = []
    
    for (rel1, rel2, rel_ac, rel_ca), count in bidirectional_rule_counts.items():
        body_count = bidirectional_body_counts.get((rel1, rel2), 0)
        
        if body_count == 0:
            continue
        
        support = count / total_triples
        confidence = count / body_count
        
        # Build rule string based on pattern type
        if pattern_type == "type1":
            rule_str = f'{rel1}(B,A) ∧ {rel2}(B,C) → {rel_ac}(A,C) ∧ {rel_ca}(C,A)'
            pattern_str = f'A←[{rel1}]B→[{rel2}]C ⇒ A↔[{rel_ac},{rel_ca}]C'
        else:  # type2
            rule_str = f'{rel1}(A,B) ∧ {rel2}(C,B) → {rel_ac}(A,C) ∧ {rel_ca}(C,A)'
            pattern_str = f'A→[{rel1}]B←[{rel2}]C ⇒ A↔[{rel_ac},{rel_ca}]C'
        
        results.append({
            'Rule': rule_str,
            'Pattern': pattern_str,
            'Relation1': rel1,
            'Relation2': rel2,
            'Rel_A_to_C': rel_ac,
            'Rel_C_to_A': rel_ca,
            'Count': count,
            'Body_Count': body_count,
            'Support': support,
            'Confidence': confidence
        })
    
    return pd.DataFrame(results).sort_values(['Confidence', 'Count'], ascending=[False, False])

# Step 7: Find examples for Type 1
def find_triangle_examples_type1(triples, outgoing, pair_to_relations, rel1, rel2, rel3, max_examples=5):
    """Find concrete examples of triangle closure Type 1: A←B→C"""
    examples = []
    
    # For each node B
    for b in outgoing:
        b_outgoing = outgoing[b]
        
        # Find all A where B→A with rel1
        a_nodes = [(a, r) for r, a in b_outgoing if r == rel1]
        # Find all C where B→C with rel2
        c_nodes = [(c, r) for r, c in b_outgoing if r == rel2]
        
        for a, _ in a_nodes:
            for c, _ in c_nodes:
                if a == c:
                    continue
                
                # Check if A→C with rel3
                if (a, c) in pair_to_relations and rel3 in pair_to_relations[(a, c)]:
                    examples.append({
                        'B': b,
                        'A': a,
                        'C': c,
                        f'{rel1}(B,A)': '✓',
                        f'{rel2}(B,C)': '✓',
                        f'{rel3}(A,C)': '✓'
                    })
                    
                    if len(examples) >= max_examples:
                        return pd.DataFrame(examples)
    
    return pd.DataFrame(examples)

# Step 8: Find examples for Type 2
def find_triangle_examples_type2(triples, incoming, pair_to_relations, rel1, rel2, rel3, max_examples=5):
    """Find concrete examples of triangle closure Type 2: A→B←C"""
    examples = []
    
    # For each node B
    for b in incoming:
        b_incoming = incoming[b]
        
        # Find all A where A→B with rel1
        a_nodes = [(a, r) for r, a in b_incoming if r == rel1]
        # Find all C where C→B with rel2
        c_nodes = [(c, r) for r, c in b_incoming if r == rel2]
        
        for a, _ in a_nodes:
            for c, _ in c_nodes:
                if a == c:
                    continue
                
                # Check if A→C with rel3
                if (a, c) in pair_to_relations and rel3 in pair_to_relations[(a, c)]:
                    examples.append({
                        'B': b,
                        'A': a,
                        'C': c,
                        f'{rel1}(A,B)': '✓',
                        f'{rel2}(C,B)': '✓',
                        f'{rel3}(A,C)': '✓'
                    })
                    
                    if len(examples) >= max_examples:
                        return pd.DataFrame(examples)
    
    return pd.DataFrame(examples)

# Main execution
print("Loading graph...")
file_path = 'train.txt'  # Change this to your file path
triples = parse_graph(file_path)

print("Building indexes...")
outgoing, incoming, pair_to_relations, persons, relations = build_graph_structures(triples)

total_triples = len(triples)
print(f"\nGraph Statistics:")
print(f"  Total triples: {total_triples}")
print(f"  Unique persons: {len(persons)}")
print(f"  Unique relations: {len(relations)}")

# Set parameters
MIN_SUPPORT = 2
MIN_CONFIDENCE = 0.1

print(f"\n{'='*100}")
print(f"Mining Triangle Closure Rules")
print(f"{'='*100}")

# ============================================================================
# TYPE 1: A←B→C ⇒ A↔C
# ============================================================================
print(f"\n{'#'*100}")
print(f"# TYPE 1: A←B→C ⇒ A↔C (B points to both A and C)")
print(f"{'#'*100}")

rule_counts_t1, body_counts_t1, bidirectional_rule_counts_t1, bidirectional_body_counts_t1 = mine_triangle_closure_type1(
    triples, outgoing, incoming, pair_to_relations, MIN_SUPPORT
)

# Type 1 - Unidirectional
print(f"\n--- Type 1 Unidirectional: A←B→C ⇒ A→C ---\n")
if rule_counts_t1:
    results_t1_df = calculate_triangle_metrics(rule_counts_t1, body_counts_t1, total_triples, "type1")
    results_t1_df = results_t1_df[results_t1_df['Confidence'] >= MIN_CONFIDENCE]
    
    print(f"Found {len(results_t1_df)} rules\n")
    print("Top 15 rules:")
    print(results_t1_df.head(15)[['Pattern', 'Count', 'Body_Count', 'Confidence']].to_string(index=False))
    
    results_t1_df.to_csv('triangle_closure_type1_unidirectional.csv', index=False)
    print(f"\nSaved to triangle_closure_type1_unidirectional.csv")
    
    # Examples
    print(f"\n{'='*100}")
    print("Examples for Top 3 Rules:")
    print(f"{'='*100}")
    for idx, row in results_t1_df.head(3).iterrows():
        print(f"\n{row['Pattern']}")
        print(f"Confidence: {row['Confidence']:.1%} | Count: {row['Count']} | Body: {row['Body_Count']}")
        
        examples = find_triangle_examples_type1(
            triples, outgoing, pair_to_relations,
            row['Relation1'], row['Relation2'], row['Relation3'],
            max_examples=3
        )
        if not examples.empty:
            print(examples.to_string(index=False))
        print("-" * 100)
else:
    print("No unidirectional rules found")

# Type 1 - Bidirectional
print(f"\n--- Type 1 Bidirectional: A←B→C ⇒ A↔C ---\n")
if bidirectional_rule_counts_t1:
    bidirectional_t1_df = calculate_bidirectional_metrics(
        bidirectional_rule_counts_t1, bidirectional_body_counts_t1, total_triples, "type1"
    )
    bidirectional_t1_df = bidirectional_t1_df[bidirectional_t1_df['Confidence'] >= MIN_CONFIDENCE]
    
    print(f"Found {len(bidirectional_t1_df)} bidirectional rules\n")
    print("Top 10 rules:")
    print(bidirectional_t1_df.head(10)[['Pattern', 'Count', 'Body_Count', 'Confidence']].to_string(index=False))
    
    bidirectional_t1_df.to_csv('triangle_closure_type1_bidirectional.csv', index=False)
    print(f"\nSaved to triangle_closure_type1_bidirectional.csv")
else:
    print("No bidirectional rules found")

# ============================================================================
# TYPE 2: A→B←C ⇒ A↔C
# ============================================================================
print(f"\n\n{'#'*100}")
print(f"# TYPE 2: A→B←C ⇒ A↔C (Both A and C point to B)")
print(f"{'#'*100}")

rule_counts_t2, body_counts_t2, bidirectional_rule_counts_t2, bidirectional_body_counts_t2 = mine_triangle_closure_type2(
    triples, outgoing, incoming, pair_to_relations, MIN_SUPPORT
)

# Type 2 - Unidirectional
print(f"\n--- Type 2 Unidirectional: A→B←C ⇒ A→C ---\n")
if rule_counts_t2:
    results_t2_df = calculate_triangle_metrics(rule_counts_t2, body_counts_t2, total_triples, "type2")
    results_t2_df = results_t2_df[results_t2_df['Confidence'] >= MIN_CONFIDENCE]
    
    print(f"Found {len(results_t2_df)} rules\n")
    print("Top 15 rules:")
    print(results_t2_df.head(15)[['Pattern', 'Count', 'Body_Count', 'Confidence']].to_string(index=False))
    
    results_t2_df.to_csv('triangle_closure_type2_unidirectional.csv', index=False)
    print(f"\nSaved to triangle_closure_type2_unidirectional.csv")
    
    # Examples
    print(f"\n{'='*100}")
    print("Examples for Top 3 Rules:")
    print(f"{'='*100}")
    for idx, row in results_t2_df.head(3).iterrows():
        print(f"\n{row['Pattern']}")
        print(f"Confidence: {row['Confidence']:.1%} | Count: {row['Count']} | Body: {row['Body_Count']}")
        
        examples = find_triangle_examples_type2(
            triples, incoming, pair_to_relations,
            row['Relation1'], row['Relation2'], row['Relation3'],
            max_examples=3
        )
        if not examples.empty:
            print(examples.to_string(index=False))
        print("-" * 100)
else:
    print("No unidirectional rules found")

# Type 2 - Bidirectional
print(f"\n--- Type 2 Bidirectional: A→B←C ⇒ A↔C ---\n")
if bidirectional_rule_counts_t2:
    bidirectional_t2_df = calculate_bidirectional_metrics(
        bidirectional_rule_counts_t2, bidirectional_body_counts_t2, total_triples, "type2"
    )
    bidirectional_t2_df = bidirectional_t2_df[bidirectional_t2_df['Confidence'] >= MIN_CONFIDENCE]
    
    print(f"Found {len(bidirectional_t2_df)} bidirectional rules\n")
    print("Top 10 rules:")
    print(bidirectional_t2_df.head(10)[['Pattern', 'Count', 'Body_Count', 'Confidence']].to_string(index=False))
    
    bidirectional_t2_df.to_csv('triangle_closure_type2_bidirectional.csv', index=False)
    print(f"\nSaved to triangle_closure_type2_bidirectional.csv")
else:
    print("No bidirectional rules found")

print(f"\n{'='*100}")
print("Triangle Closure Mining Complete!")
print(f"{'='*100}")
# Out:
# Loading graph...
# Building indexes...
#
# Graph Statistics:
#   Total triples: 13821
#   Unique persons: 1316
#   Unique relations: 28
#
# ====================================================================================================
# Mining Triangle Closure Rules
# ====================================================================================================
#
# ####################################################################################################
# # TYPE 1: A←B→C ⇒ A↔C (B points to both A and C)
# ####################################################################################################
#
# --- Type 1 Unidirectional: A←B→C ⇒ A→C ---
#
# Found 333 rules
#
# Top 15 rules:
#                                                                         Pattern  Count  Body_Count  Confidence
#                                     A←[brotherOf]B→[brotherOf]C ⇒ A→[sisterOf]C    482         431    1.118329
#                                       A←[nephewOf]B→[nephewOf]C ⇒ A→[sisterOf]C    440         403    1.091811
#                                       A←[sisterOf]B→[sisterOf]C ⇒ A→[sisterOf]C    540         511    1.056751
#                                      A←[motherOf]B→[motherOf]C ⇒ A→[brotherOf]C    454         440    1.031818
#                                      A←[fatherOf]B→[fatherOf]C ⇒ A→[brotherOf]C    454         440    1.031818
#                                       A←[motherOf]B→[motherOf]C ⇒ A→[sisterOf]C    426         440    0.968182
#                                       A←[fatherOf]B→[fatherOf]C ⇒ A→[sisterOf]C    426         440    0.968182
#                                      A←[sisterOf]B→[sisterOf]C ⇒ A→[brotherOf]C    482         511    0.943249
#                                         A←[nieceOf]B→[nieceOf]C ⇒ A→[sisterOf]C    393         425    0.924706
#                                    A←[brotherOf]B→[brotherOf]C ⇒ A→[brotherOf]C    380         431    0.881671
# A←[boyFirstCousinOnceRemovedOf]B→[boyFirstCousinOnceRemovedOf]C ⇒ A→[sisterOf]C    152         175    0.868571
#                                        A←[nieceOf]B→[nieceOf]C ⇒ A→[brotherOf]C    361         425    0.849412
#                  A←[girlSecondCousinOf]B→[girlSecondCousinOf]C ⇒ A→[brotherOf]C     34          41    0.829268
#                                      A←[nephewOf]B→[nephewOf]C ⇒ A→[brotherOf]C    304         403    0.754342
#                                 A←[boyCousinOf]B→[boyCousinOf]C ⇒ A→[sisterOf]C    337         447    0.753915
#
# Saved to triangle_closure_type1_unidirectional.csv
#
# ====================================================================================================
# Examples for Top 3 Rules:
# ====================================================================================================
#
# A←[brotherOf]B→[brotherOf]C ⇒ A→[sisterOf]C
# Confidence: 111.8% | Count: 482 | Body: 431
#      B          A          C brotherOf(B,A) brotherOf(B,C) sisterOf(A,C)
# luis14 katharina1    paula12              ✓              ✓             ✓
# luis14 katharina1  natalie13              ✓              ✓             ✓
# luis14    paula12 katharina1              ✓              ✓             ✓
# ----------------------------------------------------------------------------------------------------
#
# A←[nephewOf]B→[nephewOf]C ⇒ A→[sisterOf]C
# Confidence: 109.2% | Count: 440 | Body: 403
#      B          A          C nephewOf(B,A) nephewOf(B,C) sisterOf(A,C)
# leon16 katharina1    paula12             ✓             ✓             ✓
# leon16 katharina1  natalie13             ✓             ✓             ✓
# leon16    paula12 katharina1             ✓             ✓             ✓
# ----------------------------------------------------------------------------------------------------
#
# A←[sisterOf]B→[sisterOf]C ⇒ A→[sisterOf]C
# Confidence: 105.7% | Count: 540 | Body: 511
#       B        A          C sisterOf(B,A) sisterOf(B,C) sisterOf(A,C)
# olivia0 selina10 isabella11             ✓             ✓             ✓
# olivia0 selina10    oskar24             ✓             ✓             ✓
# olivia0 selina10      adam9             ✓             ✓             ✓
# ----------------------------------------------------------------------------------------------------
#
# --- Type 1 Bidirectional: A←B→C ⇒ A↔C ---
#
# Found 520 bidirectional rules
#
# Top 10 rules:
#                                                                             Pattern  Count  Body_Count  Confidence
#       A←[greatAuntOf]B→[grandmotherOf]C ⇒ A↔[girlSecondCousinOf,boySecondCousinOf]C     30          55    0.545455
#   A←[boySecondCousinOf]B→[sonOf]C ⇒ A↔[girlFirstCousinOnceRemovedOf,secondUncleOf]C     22          42    0.523810
#   A←[boyCousinOf]B→[boySecondCousinOf]C ⇒ A↔[boySecondCousinOf,girlSecondCousinOf]C     10          21    0.476190
#          A←[secondUncleOf]B→[fatherOf]C ⇒ A↔[girlSecondCousinOf,boySecondCousinOf]C     30          68    0.441176
#      A←[greatUncleOf]B→[grandfatherOf]C ⇒ A↔[boySecondCousinOf,girlSecondCousinOf]C     33          75    0.440000
# A←[girlCousinOf]B→[girlSecondCousinOf]C ⇒ A↔[girlSecondCousinOf,boySecondCousinOf]C     12          29    0.413793
#     A←[boySecondCousinOf]B→[brotherOf]C ⇒ A↔[girlSecondCousinOf,boySecondCousinOf]C     26          63    0.412698
#     A←[sisterOf]B→[girlSecondCousinOf]C ⇒ A↔[girlSecondCousinOf,boySecondCousinOf]C     16          41    0.390244
#           A←[boyFirstCousinOnceRemovedOf]B→[sonOf]C ⇒ A↔[girlCousinOf,boyCousinOf]C     34          90    0.377778
#                  A←[granddaughterOf]B→[greatGranddaughterOf]C ⇒ A↔[sonOf,fatherOf]C    140         374    0.374332
#
# Saved to triangle_closure_type1_bidirectional.csv
#
#
# ####################################################################################################
# # TYPE 2: A→B←C ⇒ A↔C (Both A and C point to B)
# ####################################################################################################
#
# --- Type 2 Unidirectional: A→B←C ⇒ A→C ---
#
# Found 626 rules
#
# Top 15 rules:
#                                                               Pattern  Count  Body_Count  Confidence
#               A→[secondUncleOf]B←[girlCousinOf]C ⇒ A→[secondUncleOf]C     42           5    8.400000
#      A→[girlCousinOf]B←[boySecondCousinOf]C ⇒ A→[girlSecondCousinOf]C     18           3    6.000000
#        A→[boyCousinOf]B←[boySecondCousinOf]C ⇒ A→[boySecondCousinOf]C      6           1    6.000000
#               A→[uncleOf]B←[girlSecondCousinOf]C ⇒ A→[secondUncleOf]C     57          11    5.181818
#                      A→[boyCousinOf]B←[nieceOf]C ⇒ A→[secondUncleOf]C    114          26    4.384615
#   A→[brotherOf]B←[girlFirstCousinOnceRemovedOf]C ⇒ A→[secondUncleOf]C    114          26    4.384615
#                A→[secondUncleOf]B←[boyCousinOf]C ⇒ A→[secondUncleOf]C     36           9    4.000000
#                           A→[brotherOf]B←[daughterOf]C ⇒ A→[uncleOf]C    144          40    3.600000
#                   A→[boyCousinOf]B←[daughterOf]C ⇒ A→[secondUncleOf]C     58          18    3.222222
#                          A→[uncleOf]B←[greatUncleOf]C ⇒ A→[nephewOf]C    134          43    3.116279
# A→[nieceOf]B←[boyFirstCousinOnceRemovedOf]C ⇒ A→[girlSecondCousinOf]C     62          20    3.100000
#        A→[girlSecondCousinOf]B←[brotherOf]C ⇒ A→[girlSecondCousinOf]C     34          11    3.090909
#                 A→[nephewOf]B←[granddaughterOf]C ⇒ A→[secondUncleOf]C     76          25    3.040000
#          A→[sisterOf]B←[boySecondCousinOf]C ⇒ A→[girlSecondCousinOf]C     27           9    3.000000
#                  A→[auntOf]B←[boySecondCousinOf]C ⇒ A→[secondAuntOf]C     64          22    2.909091
#
# Saved to triangle_closure_type2_unidirectional.csv
#
# ====================================================================================================
# Examples for Top 3 Rules:
# ====================================================================================================
#
# A→[secondUncleOf]B←[girlCousinOf]C ⇒ A→[secondUncleOf]C
# Confidence: 840.0% | Count: 42 | Body: 5
#           B         A           C secondUncleOf(A,B) girlCousinOf(C,B) secondUncleOf(A,C)
# victoria142 adrian155  natalie151                  ✓                 ✓                  ✓
#  dominik148 adrian155 victoria142                  ✓                 ✓                  ✓
#  natalie151 adrian155 victoria142                  ✓                 ✓                  ✓
# ----------------------------------------------------------------------------------------------------
#
# A→[girlCousinOf]B←[boySecondCousinOf]C ⇒ A→[girlSecondCousinOf]C
# Confidence: 600.0% | Count: 18 | Body: 3
#         B          A        C girlCousinOf(A,B) boySecondCousinOf(C,B) girlSecondCousinOf(A,C)
# selina774 natalie778 oskar771                 ✓                      ✓                       ✓
# selina774 natalie778 lukas772                 ✓                      ✓                       ✓
# selina774 vanessa783 oskar771                 ✓                      ✓                       ✓
# ----------------------------------------------------------------------------------------------------
#
# A→[boyCousinOf]B←[boySecondCousinOf]C ⇒ A→[boySecondCousinOf]C
# Confidence: 600.0% | Count: 6 | Body: 1
#          B          A        C boyCousinOf(A,B) boySecondCousinOf(C,B) boySecondCousinOf(A,C)
# natalie778 michael775 oskar771                ✓                      ✓                      ✓
# natalie778 michael775 lukas772                ✓                      ✓                      ✓
# vanessa783 michael775 oskar771                ✓                      ✓                      ✓
# ----------------------------------------------------------------------------------------------------
#
# --- Type 2 Bidirectional: A→B←C ⇒ A↔C ---
#
# Found 574 bidirectional rules
#
# Top 10 rules:
#                                                                 Pattern  Count  Body_Count  Confidence
#     A→[grandmotherOf]B←[sisterOf]C ⇒ A↔[grandmotherOf,granddaughterOf]C    420         420         1.0
#     A→[grandfatherOf]B←[sisterOf]C ⇒ A↔[grandfatherOf,granddaughterOf]C    410         410         1.0
#         A→[grandmotherOf]B←[brotherOf]C ⇒ A↔[grandmotherOf,grandsonOf]C    399         399         1.0
#         A→[grandfatherOf]B←[brotherOf]C ⇒ A↔[grandfatherOf,grandsonOf]C    392         392         1.0
#     A→[sisterOf]B←[grandfatherOf]C ⇒ A↔[granddaughterOf,grandfatherOf]C    337         337         1.0
#     A→[sisterOf]B←[grandmotherOf]C ⇒ A↔[granddaughterOf,grandmotherOf]C    327         327         1.0
#      A→[greatGrandfatherOf]B←[uncleOf]C ⇒ A↔[grandfatherOf,grandsonOf]C    313         313         1.0
#  A→[greatGrandfatherOf]B←[auntOf]C ⇒ A↔[grandfatherOf,granddaughterOf]C    305         305         1.0
# A→[grandmotherOf]B←[girlCousinOf]C ⇒ A↔[grandmotherOf,granddaughterOf]C    300         300         1.0
#      A→[greatGrandmotherOf]B←[uncleOf]C ⇒ A↔[grandmotherOf,grandsonOf]C    298         298         1.0
#
# Saved to triangle_closure_type2_bidirectional.csv
#
# ====================================================================================================
# Triangle Closure Mining Complete!
# ====================================================================================================
